# %%
library(quantmod)
library(fGarch)
library(repr)
library(forecast)
library(aTSA)
library(rugarch)
library(tseries)
library(aTSA)
library(MLmetrics)
# Out:
# Error: package or namespace load failed for ‘rugarch’:
#  package ‘rugarch’ was installed by an R version with different internals; it needs to be reinstalled for use with this R version
# Traceback:
#
# 1. library(rugarch)
# 2. tryCatch({
#  .     attr(package, "LibPath") <- which.lib.loc
#  .     ns <- loadNamespace(package, lib.loc)
#  .     env <- attachNamespace(ns, pos = pos, deps, exclude, include.only)
#  . }, error = function(e) {
#  .     P <- if (!is.null(cc <- conditionCall(e)))
#  .         paste(" in", deparse(cc)[1L])
#  .     else ""
#  .     msg <- gettextf("package or namespace load failed for %s%s:\n %s",
#  .         sQuote(package), P, conditionMessage(e))
#  .     if (logical.return)
#  .         message(paste("Error:", msg), domain = NA)
#  .     else stop(msg, call. = FALSE, domain = NA)
#  . })
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. value[[3L]](cond)
# 6. stop(msg, call. = FALSE, domain = NA)

# %%
install.packages(c("quantmod","fGarch","repr","forecast","aTSA","rugarch","tseries","aTSA","MLmetrics"))
# Out:
# Warning message:
# "packages 'quantmod', 'fGarch', 'repr', 'forecast', 'aTSA', 'rugarch', 'tseries', 'MLmetrics' are in use and will not be installed"

# %%
getSymbols('BABA', src = 'yahoo', return.class = 'xts',from = "2014-09-20",to="2019-12-31")
head(BABA)
BABA <- BABA[,"BABA.Close"]

plot.xts(BABA, ylab = NA)
# Out:
# [1] "BABA"
#            BABA.Open BABA.High BABA.Low BABA.Close BABA.Volume BABA.Adjusted
# 2014-09-22     92.70     92.95    89.50      89.89    66657800         89.89
# 2014-09-23     88.94     90.48    86.62      87.17    39009800         87.17
# 2014-09-24     88.47     90.57    87.22      90.57    32088000         90.57
# 2014-09-25     91.09     91.50    88.50      88.92    28598000         88.92
# 2014-09-26     89.73     90.46    88.66      90.46    18340000         90.46
# 2014-09-29     89.62     89.70    88.02      88.75    25302000         88.75
# plot without title

# %% [markdown]
# clearly non-stationary, lets calculate log returns

# %%
BABA_logret <- na.omit(diff(log(BABA)))

plot.xts(BABA_logret, ylab = NA)
hist(BABA_logret,freq=FALSE,breaks=100)
curve(dnorm(x, mean=mean(BABA_logret), sd=sd(BABA_logret)), add=TRUE, col="red")
# Out:
# plot without title
# Plot with title "Histogram of BABA_logret"

# %%
adf <- data.frame("lags"=1:10,"p-val"=NA)

for (i in 1:10){
    adf[i,"p.val"] =as.numeric(adf.test(BABA_logret, k = i)$p.val)  
}
adf
# Out:
# Warning message in adf.test(BABA_logret, k = i):
# "p-value smaller than printed p-value"Warning message in adf.test(BABA_logret, k = i):
# "p-value smaller than printed p-value"Warning message in adf.test(BABA_logret, k = i):
# "p-value smaller than printed p-value"Warning message in adf.test(BABA_logret, k = i):
# "p-value smaller than printed p-value"Warning message in adf.test(BABA_logret, k = i):
# "p-value smaller than printed p-value"Warning message in adf.test(BABA_logret, k = i):
# "p-value smaller than printed p-value"Warning message in adf.test(BABA_logret, k = i):
# "p-value smaller than printed p-value"Warning message in adf.test(BABA_logret, k = i):
# "p-value smaller than printed p-value"Warning message in adf.test(BABA_logret, k = i):
# "p-value smaller than printed p-value"Warning message in adf.test(BABA_logret, k = i):
# "p-value smaller than printed p-value"
#    lags p.val
# 1   1   0.01
# 2   2   0.01
# 3   3   0.01
# 4   4   0.01
# 5   5   0.01
# 6   6   0.01
# 7   7   0.01
# 8   8   0.01
# 9   9   0.01
# 10 10   0.01

# %% [markdown]
# stationary, lets examine ACF and PACF

# %%
par(mfrow = c(2, 1))
acf(BABA_logret)
pacf(BABA_logret)
# Out:
# Plot with title "Series  BABA_logret"

# %% [markdown]
# Also lets test joint significance of lags

# %%
LB <- data.frame("lags"=1:10,"p-val"=NA)

for (i in 1:10){
    LB[i,"p.val"] =Box.test(BABA_logret, type = "Ljung-Box", lag = i)$p.val
}
LB
# Out:
#    lags p.val
# 1   1   0.040342332
# 2   2   0.045432111
# 3   3   0.042187097
# 4   4   0.008259770
# 5   5   0.007290079
# 6   6   0.013660403
# 7   7   0.015880569
# 8   8   0.023836984
# 9   9   0.038634700
# 10 10   0.058426786

# %% [markdown]
# Null hypothesis of autocorrelations up to lag k equal zero is very likely to be rejected (according to Ljung box test)

# %% [markdown]
# From ACF and PACF as well as Box-Ljung test it appears that there is a dependence on lags in both subsamples and therefore I will proceed to GARCH.
#
# BUT from ACF/ PACF it is unclear, what order of AR or MA should be used, we will therefore focus on AIC/BIC

# %%
custom_ARIMA <- function(dat,max_p,max_q, d, const){
  model_config <-c()
  model_AIC <-c()
  model_BIC <-c()
  Ljung_Box_pval <-c()
  RMSE <- c()
  for (i in 1:(max_p+1)){
    for (j in 1:(max_q+1)){
          arima<- tryCatch(Arima(dat,  # variable
                                 order = c(i-1,d,j-1),  # (p,d,q) parameters
                                 include.constant = const),
                           warning = function(w) {print(paste("non-finite finite-difference value", ''));
                             NaN},
                           error = function(e) {print(paste("non-finite finite-difference value", ''));
                             NaN})
          
          if (!is.numeric(arima)){
            model_config <-c(model_config, 
                             paste(i-1,d,j-1,sep=',')
                             )
            model_AIC <- c(model_AIC, (AIC(arima)))
            model_BIC <- c(model_BIC, (BIC(arima)))
            Ljung_Box_pval <-c(Ljung_Box_pval,(as.numeric(sub(".*p-value = ","", 
                                                              capture.output(checkresiduals(arima, plot=FALSE)[5]))[5])))
            RMSE_tmp <-round(sqrt(mean((as.vector(arima$fitted) - as.vector(dat))^2)),1)
            RMSE <- c(RMSE, RMSE_tmp)
          }
        }
      }
  df <- as.data.frame(cbind(model_config, 
                            model_AIC,
                            as.numeric(as.character(model_BIC)),
                            as.numeric(as.character(Ljung_Box_pval)),
                            RMSE))
  names(df) <- c('model_config','model_AIC','model_BIC','Ljung_Box_pval','RMSE')
  df$model_config <- as.character(df$model_config)
  df$model_AIC <- as.numeric(as.character(df$model_AIC))
  df$model_BIC <- as.numeric(as.character(df$model_BIC))
  df$Ljung_Box_pval <- as.numeric(as.character(df$Ljung_Box_pval))
  return(df)
}

custom_ARIMA_results <- custom_ARIMA(BABA_logret, 10, 10, 0, FALSE)

# %%
head(custom_ARIMA_results[order(custom_ARIMA_results$model_AIC),],5)

head(custom_ARIMA_results[order(custom_ARIMA_results$model_BIC),],5)
# Out:
#    model_config model_AIC model_BIC Ljung_Box_pval RMSE
# 25 2,0,2        -6619.924 -6593.971 0.8801         0
# 36 3,0,2        -6618.770 -6587.626 0.9694         0
# 26 2,0,3        -6618.710 -6587.566 0.9692         0
# 47 4,0,2        -6616.978 -6580.644 0.9447         0
# 27 2,0,4        -6616.932 -6580.598 0.9385         0
#    model_config model_AIC model_BIC Ljung_Box_pval RMSE
# 1  0,0,0        -6607.626 -6602.435 0.05843        0
# 2  0,0,1        -6610.337 -6599.956 0.08985        0
# 12 1,0,0        -6609.990 -6599.608 0.08249        0
# 23 2,0,0        -6610.231 -6594.659 0.11550        0
# 3  0,0,2        -6609.571 -6593.999 0.09953        0

# %%
auto.arima(BABA_logret,ic ="aic")
# Out:
# Series: BABA_logret
# ARIMA(2,0,3) with zero mean
#
# Coefficients:
#           ar1      ar2     ma1     ma2      ma3
#       -0.8706  -0.6276  0.9366  0.6474  -0.0422
# s.e.   0.1394   0.1962  0.1406  0.2100   0.0403
#
# sigma^2 estimated as 0.0003973:  log likelihood=3315.36
# AIC=-6618.71   AICc=-6618.65   BIC=-6587.57

# %% [markdown]
# # proc to neodpovida nasi tabulce??
#
# zatim jsem vybral jen tu 2-0-2, muzeme vzit jinou/ vice zaroven

# %%
arima202 <- arima(BABA_logret, order = c(2, 0, 2))
arima202
arch.test(arima202)
# Out:
# Call:
# arima(x = BABA_logret, order = c(2, 0, 2))
#
# Coefficients:
#           ar1      ar2     ma1     ma2  intercept
#       -0.9759  -0.7847  1.0521  0.8348      7e-04
# s.e.   0.0939   0.1113  0.0790  0.1011      6e-04
#
# sigma^2 estimated as 0.0003956:  log likelihood = 3315.61,  aic = -6619.21
# ARCH heteroscedasticity test for residuals
# alternative: heteroscedastic
#
# Portmanteau-Q test:
#      order   PQ p.value
# [1,]     4 11.6 0.02053
# [2,]     8 19.5 0.01233
# [3,]    12 28.6 0.00455
# [4,]    16 33.6 0.00612
# [5,]    20 38.5 0.00758
# [6,]    24 45.9 0.00455
# Lagrange-Multiplier test:
#      order  LM p.value
# [1,]     4 986       0
# [2,]     8 478       0
# [3,]    12 307       0
# [4,]    16 226       0
# [5,]    20 178       0
# [6,]    24 145       0
# plot without title

# %% [markdown]
# homoskedastic residuals rejected => focus on conditional volatility (GARCH family models)

# %% [markdown]
# # Conditional volatility

# %% [markdown]
# We start with ARMA(2,0,2)-GARCH(1,1) and save last 183 observations (6 months) for out of sample forecasting

# %%
arma202_garch11_spec = ugarchspec(mean.model = list(armaOrder=c(2, 2)), variance.model = list(model = "sGARCH", garchOrder = c(1, 1)))

arma202_garch11= ugarchfit(arma202_garch11_spec, BABA_logret, out.sample = 183)

arma202_garch11
# Out:
# *---------------------------------*
# *          GARCH Model Fit        *
# *---------------------------------*
#
# Conditional Variance Dynamics
# -----------------------------------
# GARCH Model	: sGARCH(1,1)
# Mean Model	: ARFIMA(2,0,2)
# Distribution	: norm
#
# Optimal Parameters
# ------------------------------------
#         Estimate  Std. Error  t value Pr(>|t|)
# mu      0.000920    0.000608   1.5129 0.130300
# ar1    -0.878334    0.166811  -5.2654 0.000000
# ar2    -0.711356    0.109670  -6.4863 0.000000
# ma1     0.968409    0.154391   6.2724 0.000000
# ma2     0.767792    0.109358   7.0209 0.000000
# omega   0.000025    0.000012   2.0988 0.035833
# alpha1  0.041716    0.015024   2.7766 0.005494
# beta1   0.894758    0.041652  21.4818 0.000000
#
# Robust Standard Errors:
#         Estimate  Std. Error  t value Pr(>|t|)
# mu      0.000920    0.000571   1.6126 0.106841
# ar1    -0.878334    0.197783  -4.4409 0.000009
# ar2    -0.711356    0.129766  -5.4818 0.000000
# ma1     0.968409    0.182936   5.2937 0.000000
# ma2     0.767792    0.137343   5.5903 0.000000
# omega   0.000025    0.000019   1.3076 0.191002
# alpha1  0.041716    0.020494   2.0355 0.041803
# beta1   0.894758    0.056727  15.7730 0.000000
#
# LogLikelihood : 2863.14
#
# Information Criteria
# ------------------------------------
#
# Akaike       -4.9915
# Bayes        -4.9562
# Shibata      -4.9916
# Hannan-Quinn -4.9782
#
# Weighted Ljung-Box Test on Standardized Residuals
# ------------------------------------
#                          statistic p-value
# Lag[1]                      0.3743  0.5406
# Lag[2*(p+q)+(p+q)-1][11]    1.5335  1.0000
# Lag[4*(p+q)+(p+q)-1][19]    6.7491  0.9287
# d.o.f=4
# H0 : No serial correlation
#
# Weighted Ljung-Box Test on Standardized Squared Residuals
# ------------------------------------
#                         statistic p-value
# Lag[1]                     0.4959  0.4813
# Lag[2*(p+q)+(p+q)-1][5]    0.9585  0.8690
# Lag[4*(p+q)+(p+q)-1][9]    1.5053  0.9551
# d.o.f=2
#
# Weighted ARCH LM Tests
# ------------------------------------
#             Statistic Shape Scale P-Value
# ARCH Lag[3]   0.06088 0.500 2.000  0.8051
# ARCH Lag[5]   0.33338 1.440 1.667  0.9313
# ARCH Lag[7]   0.60707 2.315 1.543  0.9677
#
# Nyblom stability test
# ------------------------------------
# Joint Statistic:  1.0089
# Individual Statistics:
# mu     0.16665
# ar1    0.11979
# ar2    0.09303
# ma1    0.09108
# ma2    0.08381
# omega  0.04709
# alpha1 0.15634
# beta1  0.06812
#
# Asymptotic Critical Values (10% 5% 1%)
# Joint Statistic:     	 1.89 2.11 2.59
# Individual Statistic:	 0.35 0.47 0.75
#
# Sign Bias Test
# ------------------------------------
#                    t-value   prob sig
# Sign Bias           1.6286 0.1037
# Negative Sign Bias  1.5732 0.1160
# Positive Sign Bias  0.5232 0.6009
# Joint Effect        3.3978 0.3343
#
#
# Adjusted Pearson Goodness-of-Fit Test:
# ------------------------------------
#   group statistic p-value(g-1)
# 1    20     62.33    1.648e-06
# 2    30     72.73    1.271e-05
# 3    40     76.00    3.565e-04
# 4    50     89.65    3.520e-04
#
#
# Elapsed time : 0.2893748

# %% [markdown]
# From the results we can see that all coefficients except mean are significant and null hypothesis of no autocorellation cannot be rejected (Ljung Box test).

# %% [markdown]
# Testing normality

# %%
jarque.bera.test(residuals(arma202_garch11))

par(mfrow = c(1, 2))

hist(residuals(arma202_garch11), breaks = 30, main ='Histogram', cex.main = 0.8, cex.lab = 0.8, xlab = NA,
    cex.axis = 0.8)
box()

qqnorm(residuals(arma202_garch11), cex.main = 0.8, cex.lab = 0.8, cex.axis = 0.8) 
qqline(residuals(arma202_garch11), lwd = 2)
# Out:
# 	Jarque Bera Test
#
# data:  residuals(arma202_garch11)
# X-squared = 258.57, df = 2, p-value < 2.2e-16
# Plot with title "Normal Q-Q Plot"

# %% [markdown]
# residuals do not appear to be normally distributed, lets fit residuals having students t-distribution

# %%
arma202_garch11_t_spec = ugarchspec(mean.model = list(armaOrder=c(2, 2)), variance.model = list(model = "sGARCH", garchOrder = c(1, 1)),distribution.model = 'std')

arma202_garch11_t= ugarchfit(arma202_garch11_t_spec, BABA_logret, out.sample = 183)

arma202_garch11_t
# Out:
# *---------------------------------*
# *          GARCH Model Fit        *
# *---------------------------------*
#
# Conditional Variance Dynamics
# -----------------------------------
# GARCH Model	: sGARCH(1,1)
# Mean Model	: ARFIMA(2,0,2)
# Distribution	: std
#
# Optimal Parameters
# ------------------------------------
#         Estimate  Std. Error  t value Pr(>|t|)
# mu      0.000714    0.000537   1.3288 0.183909
# ar1    -0.942160    0.129336  -7.2846 0.000000
# ar2    -0.721275    0.108322  -6.6586 0.000000
# ma1     1.016237    0.115812   8.7749 0.000000
# ma2     0.786074    0.098681   7.9658 0.000000
# omega   0.000008    0.000004   2.1183 0.034149
# alpha1  0.050876    0.006016   8.4564 0.000000
# beta1   0.931877    0.011528  80.8356 0.000000
# shape   5.604840    0.765032   7.3263 0.000000
#
# Robust Standard Errors:
#         Estimate  Std. Error  t value Pr(>|t|)
# mu      0.000714    0.000481   1.4841 0.137778
# ar1    -0.942160    0.134508  -7.0045 0.000000
# ar2    -0.721275    0.118550  -6.0842 0.000000
# ma1     1.016237    0.120683   8.4207 0.000000
# ma2     0.786074    0.113081   6.9514 0.000000
# omega   0.000008    0.000005   1.5642 0.117776
# alpha1  0.050876    0.010116   5.0293 0.000000
# beta1   0.931877    0.012366  75.3557 0.000000
# shape   5.604840    1.161555   4.8253 0.000001
#
# LogLikelihood : 2907.27
#
# Information Criteria
# ------------------------------------
#
# Akaike       -5.0669
# Bayes        -5.0272
# Shibata      -5.0670
# Hannan-Quinn -5.0519
#
# Weighted Ljung-Box Test on Standardized Residuals
# ------------------------------------
#                          statistic p-value
# Lag[1]                    0.002392  0.9610
# Lag[2*(p+q)+(p+q)-1][11]  1.753602  1.0000
# Lag[4*(p+q)+(p+q)-1][19]  7.313770  0.8781
# d.o.f=4
# H0 : No serial correlation
#
# Weighted Ljung-Box Test on Standardized Squared Residuals
# ------------------------------------
#                         statistic p-value
# Lag[1]                     0.1990  0.6556
# Lag[2*(p+q)+(p+q)-1][5]    0.9867  0.8627
# Lag[4*(p+q)+(p+q)-1][9]    1.4691  0.9581
# d.o.f=2
#
# Weighted ARCH LM Tests
# ------------------------------------
#             Statistic Shape Scale P-Value
# ARCH Lag[3]    0.3120 0.500 2.000  0.5764
# ARCH Lag[5]    0.8548 1.440 1.667  0.7765
# ARCH Lag[7]    0.9869 2.315 1.543  0.9157
#
# Nyblom stability test
# ------------------------------------
# Joint Statistic:  4.0482
# Individual Statistics:
# mu     0.25463
# ar1    0.10982
# ar2    0.06581
# ma1    0.08312
# ma2    0.08111
# omega  0.19660
# alpha1 0.22791
# beta1  0.16110
# shape  0.37422
#
# Asymptotic Critical Values (10% 5% 1%)
# Joint Statistic:     	 2.1 2.32 2.82
# Individual Statistic:	 0.35 0.47 0.75
#
# Sign Bias Test
# ------------------------------------
#                    t-value    prob sig
# Sign Bias           1.6754 0.09412   *
# Negative Sign Bias  0.9648 0.33484
# Positive Sign Bias  0.8347 0.40404
# Joint Effect        2.8230 0.41972
#
#
# Adjusted Pearson Goodness-of-Fit Test:
# ------------------------------------
#   group statistic p-value(g-1)
# 1    20     38.55    0.0050443
# 2    30     60.41    0.0005498
# 3    40     65.79    0.0046454
# 4    50     76.80    0.0067708
#
#
# Elapsed time : 0.4186831

# %%
jarque.bera.test(residuals(arma202_garch11_t))

par(mfrow = c(1, 2))

hist(residuals(arma202_garch11_t), breaks = 30, main ='Histogram', cex.main = 0.8, cex.lab = 0.8, xlab = NA,
    cex.axis = 0.8)
box()

qqnorm(residuals(arma202_garch11_t), cex.main = 0.8, cex.lab = 0.8, cex.axis = 0.8) 
qqline(residuals(arma202_garch11_t), lwd = 2)
# Out:
# 	Jarque Bera Test
#
# data:  residuals(arma202_garch11_t)
# X-squared = 264.52, df = 2, p-value < 2.2e-16
# Plot with title "Normal Q-Q Plot"

# %% [markdown]
# # Vubec to nepomohlo? smazat?

# %% [markdown]
# Lets try to fit models from GARCH family that account for asymmetric responses, namely EGARCH and GJRGARCH.
# Starting with ARMA(2,0,2)-EGARCH(1,1)

# %%
arma202_egarch11_spec <- ugarchspec(mean.model = list(armaOrder=c(2, 2)), variance.model = list(model = "eGARCH", 
                      garchOrder = c(1, 1)))


arma202_egarch11 = ugarchfit(arma202_egarch11_spec, BABA_logret, out.sample = 183)
arma202_egarch11
# Out:
# *---------------------------------*
# *          GARCH Model Fit        *
# *---------------------------------*
#
# Conditional Variance Dynamics
# -----------------------------------
# GARCH Model	: eGARCH(1,1)
# Mean Model	: ARFIMA(2,0,2)
# Distribution	: norm
#
# Optimal Parameters
# ------------------------------------
#         Estimate  Std. Error   t value Pr(>|t|)
# mu      0.000729    0.000355    2.0550 0.039881
# ar1    -0.879323    0.138433   -6.3520 0.000000
# ar2    -0.701238    0.186740   -3.7551 0.000173
# ma1     0.959121    0.138674    6.9164 0.000000
# ma2     0.747751    0.156433    4.7800 0.000002
# omega  -0.437638    0.003421 -127.9173 0.000000
# alpha1 -0.040160    0.014866   -2.7015 0.006902
# beta1   0.943780    0.000425 2220.0680 0.000000
# gamma1  0.073860    0.003233   22.8438 0.000000
#
# Robust Standard Errors:
#         Estimate  Std. Error   t value Pr(>|t|)
# mu      0.000729    0.000220    3.3083 0.000939
# ar1    -0.879323    0.144053   -6.1042 0.000000
# ar2    -0.701238    0.364912   -1.9217 0.054648
# ma1     0.959121    0.163661    5.8604 0.000000
# ma2     0.747751    0.296110    2.5252 0.011562
# omega  -0.437638    0.006032  -72.5503 0.000000
# alpha1 -0.040160    0.022119   -1.8157 0.069418
# beta1   0.943780    0.000801 1178.2050 0.000000
# gamma1  0.073860    0.002137   34.5631 0.000000
#
# LogLikelihood : 2868.922
#
# Information Criteria
# ------------------------------------
#
# Akaike       -4.9999
# Bayes        -4.9602
# Shibata      -5.0000
# Hannan-Quinn -4.9849
#
# Weighted Ljung-Box Test on Standardized Residuals
# ------------------------------------
#                          statistic p-value
# Lag[1]                      0.3592  0.5490
# Lag[2*(p+q)+(p+q)-1][11]    1.7830  1.0000
# Lag[4*(p+q)+(p+q)-1][19]    7.4788  0.8601
# d.o.f=4
# H0 : No serial correlation
#
# Weighted Ljung-Box Test on Standardized Squared Residuals
# ------------------------------------
#                         statistic p-value
# Lag[1]                      1.778  0.1824
# Lag[2*(p+q)+(p+q)-1][5]     2.094  0.5965
# Lag[4*(p+q)+(p+q)-1][9]     2.505  0.8370
# d.o.f=2
#
# Weighted ARCH LM Tests
# ------------------------------------
#             Statistic Shape Scale P-Value
# ARCH Lag[3]   0.01362 0.500 2.000  0.9071
# ARCH Lag[5]   0.19488 1.440 1.667  0.9667
# ARCH Lag[7]   0.28830 2.315 1.543  0.9934
#
# Nyblom stability test
# ------------------------------------
# Joint Statistic:  1.3788
# Individual Statistics:
# mu     0.09240
# ar1    0.12070
# ar2    0.08270
# ma1    0.09870
# ma2    0.08220
# omega  0.03222
# alpha1 0.23344
# beta1  0.03062
# gamma1 0.05363
#
# Asymptotic Critical Values (10% 5% 1%)
# Joint Statistic:     	 2.1 2.32 2.82
# Individual Statistic:	 0.35 0.47 0.75
#
# Sign Bias Test
# ------------------------------------
#                    t-value   prob sig
# Sign Bias          1.52409 0.1278
# Negative Sign Bias 1.21747 0.2237
# Positive Sign Bias 0.09868 0.9214
# Joint Effect       3.45294 0.3269
#
#
# Adjusted Pearson Goodness-of-Fit Test:
# ------------------------------------
#   group statistic p-value(g-1)
# 1    20     53.45    4.006e-05
# 2    30     63.97    1.931e-04
# 3    40     83.06    5.049e-05
# 4    50     97.00    5.314e-05
#
#
# Elapsed time : 0.2733221

# %% [markdown]
# and GJRGARCH

# %%
arma202_gjrgarch11_spec <- ugarchspec(mean.model = list(armaOrder=c(2, 2)), variance.model = list(model = "gjrGARCH", 
                      garchOrder = c(1, 1)))

arma202_gjrgarch11 = ugarchfit(arma202_gjrgarch11_spec, BABA_logret, out.sample = 183)
arma202_gjrgarch11
# Out:
# *---------------------------------*
# *          GARCH Model Fit        *
# *---------------------------------*
#
# Conditional Variance Dynamics
# -----------------------------------
# GARCH Model	: gjrGARCH(1,1)
# Mean Model	: ARFIMA(2,0,2)
# Distribution	: norm
#
# Optimal Parameters
# ------------------------------------
#         Estimate  Std. Error  t value Pr(>|t|)
# mu      0.000700    0.000603  1.16028 0.245934
# ar1    -0.907928    0.212794 -4.26670 0.000020
# ar2    -0.691828    0.150145 -4.60773 0.000004
# ma1     0.986992    0.199718  4.94193 0.000001
# ma2     0.747164    0.142337  5.24926 0.000000
# omega   0.000023    0.000012  1.99903 0.045605
# alpha1  0.003882    0.009963  0.38963 0.696811
# beta1   0.905146    0.041367 21.88104 0.000000
# gamma1  0.066416    0.024605  2.69924 0.006950
#
# Robust Standard Errors:
#         Estimate  Std. Error  t value Pr(>|t|)
# mu      0.000700    0.000577  1.21254 0.225305
# ar1    -0.907928    0.256664 -3.53742 0.000404
# ar2    -0.691828    0.195157 -3.54498 0.000393
# ma1     0.986992    0.238886  4.13165 0.000036
# ma2     0.747164    0.186142  4.01394 0.000060
# omega   0.000023    0.000019  1.24507 0.213104
# alpha1  0.003882    0.013824  0.28079 0.778869
# beta1   0.905146    0.057021 15.87386 0.000000
# gamma1  0.066416    0.027903  2.38020 0.017303
#
# LogLikelihood : 2870.431
#
# Information Criteria
# ------------------------------------
#
# Akaike       -5.0025
# Bayes        -4.9628
# Shibata      -5.0026
# Hannan-Quinn -4.9875
#
# Weighted Ljung-Box Test on Standardized Residuals
# ------------------------------------
#                          statistic p-value
# Lag[1]                      0.2092  0.6474
# Lag[2*(p+q)+(p+q)-1][11]    1.4048  1.0000
# Lag[4*(p+q)+(p+q)-1][19]    7.1121  0.8981
# d.o.f=4
# H0 : No serial correlation
#
# Weighted Ljung-Box Test on Standardized Squared Residuals
# ------------------------------------
#                         statistic p-value
# Lag[1]                      1.755  0.1852
# Lag[2*(p+q)+(p+q)-1][5]     2.175  0.5777
# Lag[4*(p+q)+(p+q)-1][9]     2.657  0.8140
# d.o.f=2
#
# Weighted ARCH LM Tests
# ------------------------------------
#             Statistic Shape Scale P-Value
# ARCH Lag[3]   0.04003 0.500 2.000  0.8414
# ARCH Lag[5]   0.30460 1.440 1.667  0.9390
# ARCH Lag[7]   0.43814 2.315 1.543  0.9836
#
# Nyblom stability test
# ------------------------------------
# Joint Statistic:  1.1301
# Individual Statistics:
# mu     0.07097
# ar1    0.10529
# ar2    0.11072
# ma1    0.08973
# ma2    0.11044
# omega  0.03716
# alpha1 0.12114
# beta1  0.04699
# gamma1 0.10858
#
# Asymptotic Critical Values (10% 5% 1%)
# Joint Statistic:     	 2.1 2.32 2.82
# Individual Statistic:	 0.35 0.47 0.75
#
# Sign Bias Test
# ------------------------------------
#                    t-value   prob sig
# Sign Bias            1.486 0.1377
# Negative Sign Bias   1.084 0.2788
# Positive Sign Bias   0.141 0.8879
# Joint Effect         3.392 0.3350
#
#
# Adjusted Pearson Goodness-of-Fit Test:
# ------------------------------------
#   group statistic p-value(g-1)
# 1    20     51.35    8.274e-05
# 2    30     60.35    5.581e-04
# 3    40     65.79    4.645e-03
# 4    50     88.43    4.762e-04
#
#
# Elapsed time : 0.8288331

# %% [markdown]
# # jeste zkusit jine? EWMA?

# %% [markdown]
# Lets compare coefficients from all models

# %%
coefficients <- cbind(coef(arma202_garch11),
                        coef(arma202_egarch11),
                        coef(arma202_gjrgarch11))

colnames(coefficients) <- c("ARMA(2,0,2)-GARCH(1,1)","ARMA(2,0,2)-EGARCH(1,1)","ARMA(2,0,2)-GJRGARCH(1,1)")
coefficients
# Out:
# Warning message in cbind(coef(arma202_garch11), coef(arma202_egarch11), coef(arma202_gjrgarch11)):
# "number of rows of result is not a multiple of vector length (arg 1)"
#        ARMA(2,0,2)-GARCH(1,1) ARMA(2,0,2)-EGARCH(1,1) ARMA(2,0,2)-GJRGARCH(1,1)
# mu      9.200962e-04           0.0007287029            6.995580e-04
# ar1    -8.783335e-01          -0.8793226093           -9.079282e-01
# ar2    -7.113557e-01          -0.7012377754           -6.918279e-01
# ma1     9.684091e-01           0.9591214188            9.869916e-01
# ma2     7.677923e-01           0.7477508830            7.471639e-01
# omega   2.544038e-05          -0.4376377180            2.338583e-05
# alpha1  4.171554e-02          -0.0401604780            3.881815e-03
# beta1   8.947575e-01           0.9437800981            9.051458e-01
# gamma1  9.200962e-04           0.0738599180            6.641563e-02

# %% [markdown]
# And lets check which model performs the best according to AIC

# %% [markdown]
# # mozna srovnat i jinak? jine kriteria, mozna RMSE?

# %%
performance <- cbind(c(infocriteria(arma202_garch11)["Akaike",],
                        infocriteria(arma202_egarch11)["Akaike",],
                        infocriteria(arma202_gjrgarch11)["Akaike",]))
rownames(performance) <- c("ARMA(2,0,2)-GARCH(1,1)","ARMA(2,0,2)-EGARCH(1,1)","ARMA(2,0,2)-GJRGARCH(1,1)")
performance
# Out:
#                           [,1]
# ARMA(2,0,2)-GARCH(1,1)    -4.991503
# ARMA(2,0,2)-EGARCH(1,1)   -4.999863
# ARMA(2,0,2)-GJRGARCH(1,1) -5.002501

# %% [markdown]
# Now lets perform dynamic forecast and set the forecast horizon to 6 months

# %%
forecast_arma202_garch11 = ugarchforecast(arma202_garch11, n.ahead = 1, n.roll = 183)
forecast_arma202_egarch11 = ugarchforecast(arma202_egarch11, n.ahead = 1, n.roll = 183)
forecast_arma202_gjrgarch11 = ugarchforecast(arma202_gjrgarch11, n.ahead = 1, n.roll = 183)

# %%
par(mfrow = c(1, 1))
plot.ts(arma202_garch11@fit$sigma, ylab = NA, xlim = c(0, length(BABA_logret)), main = 'Volatility forecasts')
lines(c(rep(NA, length(BABA_logret) - 183 - 1), forecast_arma202_garch11@forecast$sigma), col = 'red')

lines(c(rep(NA, length(BABA_logret) - 183 - 1), forecast_arma202_egarch11@forecast$sigma), col = 'blue')

lines(c(rep(NA, length(BABA_logret) - 183 - 1), forecast_arma202_gjrgarch11@forecast$sigma), col = 'orange')
# Out:
# Plot with title "Volatility forecasts"

# %% [markdown]
# From the graphs we can see that they produce similar predictions, lets examine MSE.
#
# First I bind the prediction vectors

# %%
predictions  <- cbind(forecast_arma202_garch11@forecast$sigmaFor[1:183],
                      forecast_arma202_egarch11@forecast$sigmaFor[1:183],
                      forecast_arma202_gjrgarch11@forecast$sigmaFor[1:183])

# %% [markdown]
# Then I calculate volatility proxy

# %%
vol <- (tail(BABA_logret,183))^2

# %% [markdown]
# And finally proceed to MSE

# %%
MSE_results <- cbind(MSE(y_pred = predictions[1], y_true = vol),
                     MSE(y_pred = predictions[2], y_true = vol),
                     MSE(y_pred = predictions[3], y_true = vol))


colnames(MSE_results) <- c('ARMA(2,0,2)-GARCH(1,1)',
                          'ARMA(2,0,2)-eGARCH(1,1)',
                          'ARMA(2,0,2)-gjrGARCH(1,1)')

MSE_results
# Out:
#      ARMA(2,0,2)-GARCH(1,1) ARMA(2,0,2)-eGARCH(1,1) ARMA(2,0,2)-gjrGARCH(1,1)
# [1,] 0.0003113915           0.0003041267            0.000299578

# %% [markdown]
# ARMA(2,0,2)-gjrGARCH(1,1) appears to perform best in terms of mean squared error
