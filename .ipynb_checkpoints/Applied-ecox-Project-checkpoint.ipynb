# %%
library(quantmod)
library(fGarch)
library(repr)
library(forecast)
library(aTSA)
library(rugarch)
library(tseries)
library(aTSA)
library(MLmetrics)

# %%
getSymbols('BABA', src = 'yahoo', return.class = 'xts',from = "2014-09-20",to="2019-12-31")
head(BABA)
BABA <- BABA[,"BABA.Close"]
plot.xts(BABA, ylab = NA)
# Out:
# 'getSymbols' currently uses auto.assign=TRUE by default, but will
# use auto.assign=FALSE in 0.5-0. You will still be able to use
# 'loadSymbols' to automatically load data. getOption("getSymbols.env")
# and getOption("getSymbols.auto.assign") will still be checked for
# alternate defaults.
#
# This message is shown once per session and may be disabled by setting
# options("getSymbols.warning4.0"=FALSE). See ?getSymbols for details.
# [1] "BABA"
#            BABA.Open BABA.High BABA.Low BABA.Close BABA.Volume BABA.Adjusted
# 2014-09-22     92.70     92.95    89.50      89.89    66657800         89.89
# 2014-09-23     88.94     90.48    86.62      87.17    39009800         87.17
# 2014-09-24     88.47     90.57    87.22      90.57    32088000         90.57
# 2014-09-25     91.09     91.50    88.50      88.92    28598000         88.92
# 2014-09-26     89.73     90.46    88.66      90.46    18340000         90.46
# 2014-09-29     89.62     89.70    88.02      88.75    25302000         88.75
# plot without title

# %% [markdown]
# clearly non-stationary, lets calculate log returns

# %%
BABA_logret <- na.omit(diff(log(BABA)))

plot.xts(BABA_logret, ylab = NA)
hist(BABA_logret,freq=FALSE,breaks=100)
curve(dnorm(x, mean=mean(BABA_logret), sd=sd(BABA_logret)), add=TRUE, col="red")
# Out:
# plot without title
# Plot with title "Histogram of BABA_logret"

# %%
adf <- data.frame("lags"=1:10,"p-val"=NA)

for (i in 1:10){
    adf[i,"p.val"] =as.numeric(adf.test(BABA_logret, k = i)$p.val)  
}
adf
# Out:
# Warning message in adf.test(BABA_logret, k = i):
# "p-value smaller than printed p-value"Warning message in adf.test(BABA_logret, k = i):
# "p-value smaller than printed p-value"Warning message in adf.test(BABA_logret, k = i):
# "p-value smaller than printed p-value"Warning message in adf.test(BABA_logret, k = i):
# "p-value smaller than printed p-value"Warning message in adf.test(BABA_logret, k = i):
# "p-value smaller than printed p-value"Warning message in adf.test(BABA_logret, k = i):
# "p-value smaller than printed p-value"Warning message in adf.test(BABA_logret, k = i):
# "p-value smaller than printed p-value"Warning message in adf.test(BABA_logret, k = i):
# "p-value smaller than printed p-value"Warning message in adf.test(BABA_logret, k = i):
# "p-value smaller than printed p-value"Warning message in adf.test(BABA_logret, k = i):
# "p-value smaller than printed p-value"
#    lags p.val
# 1   1   0.01
# 2   2   0.01
# 3   3   0.01
# 4   4   0.01
# 5   5   0.01
# 6   6   0.01
# 7   7   0.01
# 8   8   0.01
# 9   9   0.01
# 10 10   0.01

# %% [markdown]
# stationary, lets examine ACF and PACF

# %%
par(mfrow = c(2, 1))
acf(BABA_logret)
pacf(BABA_logret)
# Out:
# Plot with title "Series  BABA_logret"

# %% [markdown]
# Also lets test joint significance of lags

# %%
LB <- data.frame("lags"=1:10,"p-val"=NA)

for (i in 1:10){
    LB[i,"p.val"] =Box.test(BABA_logret, type = "Ljung-Box", lag = i)$p.val
}
LB
# Out:
#    lags p.val
# 1   1   0.040342332
# 2   2   0.045432111
# 3   3   0.042187097
# 4   4   0.008259770
# 5   5   0.007290079
# 6   6   0.013660403
# 7   7   0.015880569
# 8   8   0.023836984
# 9   9   0.038634700
# 10 10   0.058426786

# %% [markdown]
# Null hypothesis of autocorrelations up to lag k equal zero is very likely to be rejected (according to Ljung box test)

# %% [markdown]
# From ACF and PACF as well as Box-Ljung test it appears that there is no dependence on lags in both subsamples and therefore I will proceed to GARCH.

# %% [markdown]
# Now, lets fit only mean and test for heteroskedasticity

# %%
arima101 <- arima(BABA_logret, order = c(1, 0, 1))
arima101
arch.test(arima101)
# Out:
# Call:
# arima(x = BABA_logret, order = c(1, 0, 1))
#
# Coefficients:
#           ar1     ma1  intercept
#       -0.1673  0.2281      6e-04
# s.e.   0.2227  0.2184      6e-04
#
# sigma^2 estimated as 0.0004002:  log likelihood = 3308.02,  aic = -6608.04
# ARCH heteroscedasticity test for residuals
# alternative: heteroscedastic
#
# Portmanteau-Q test:
#      order   PQ p.value
# [1,]     4 14.4 0.00618
# [2,]     8 23.4 0.00285
# [3,]    12 31.8 0.00147
# [4,]    16 35.8 0.00306
# [5,]    20 40.8 0.00399
# [6,]    24 46.9 0.00345
# Lagrange-Multiplier test:
#      order  LM p.value
# [1,]     4 983       0
# [2,]     8 476       0
# [3,]    12 307       0
# [4,]    16 227       0
# [5,]    20 178       0
# [6,]    24 146       0
# plot without title

# %%
custom_ARIMA <- function(dat,max_p,max_q, d, const){
  model_config <-c()
  model_AIC <-c()
  model_BIC <-c()
  Ljung_Box_pval <-c()
  RMSE <- c()
  for (i in 1:(max_p+1)){
    for (j in 1:(max_q+1)){
          arima<- tryCatch(Arima(dat,  # variable
                                 order = c(i-1,d,j-1),  # (p,d,q) parameters
                                 include.constant = const),
                           warning = function(w) {print(paste("non-finite finite-difference value", ''));
                             NaN},
                           error = function(e) {print(paste("non-finite finite-difference value", ''));
                             NaN})
          
          print(paste(i-1,d,j-1,sep = '_'))
          if (!is.numeric(arima)){
            model_config <-c(model_config, 
                             paste(i-1,d,j-1,sep=',')
                             )
            model_AIC <- c(model_AIC, (AIC(arima)))
            model_BIC <- c(model_BIC, (BIC(arima)))
            Ljung_Box_pval <-c(Ljung_Box_pval,(as.numeric(sub(".*p-value = ","", 
                                                              capture.output(checkresiduals(arima, plot=FALSE)[5]))[5])))
            RMSE_tmp <-round(sqrt(mean((as.vector(arima$fitted) - as.vector(dat))^2)),1)
            RMSE <- c(RMSE, RMSE_tmp)
          }
        }
      }
  df <- as.data.frame(cbind(model_config, 
                            model_AIC,
                            as.numeric(as.character(model_BIC)),
                            as.numeric(as.character(Ljung_Box_pval)),
                            RMSE))
  names(df) <- c('model_config','model_AIC','model_BIC','Ljung_Box_pval','RMSE')
  df$model_config <- as.character(df$model_config)
  df$model_AIC <- as.numeric(as.character(df$model_AIC))
  df$model_BIC <- as.numeric(as.character(df$model_BIC))
  df$Ljung_Box_pval <- as.numeric(as.character(df$Ljung_Box_pval))
  return(df)
}

custom_ARIMA_results <- custom_ARIMA(BABA_logret, 10, 10, 0, FALSE)
# Out:
# [1] "0_0_0"
# [1] "0_0_1"
# [1] "0_0_2"
# [1] "0_0_3"
# [1] "0_0_4"
# [1] "0_0_5"
# [1] "0_0_6"
# [1] "0_0_7"
# [1] "0_0_8"
# [1] "0_0_9"
# [1] "0_0_10"
# [1] "1_0_0"
# [1] "1_0_1"
# [1] "1_0_2"
# [1] "1_0_3"
# [1] "1_0_4"
# [1] "1_0_5"
# [1] "1_0_6"
# [1] "1_0_7"
# [1] "1_0_8"
# [1] "1_0_9"
# [1] "1_0_10"
# [1] "2_0_0"
# [1] "2_0_1"
# [1] "2_0_2"
# [1] "2_0_3"
# [1] "2_0_4"
# [1] "2_0_5"
# [1] "2_0_6"
# [1] "2_0_7"
# [1] "2_0_8"
# [1] "2_0_9"
# [1] "2_0_10"
# [1] "3_0_0"
# [1] "3_0_1"
# [1] "3_0_2"
# [1] "3_0_3"
# [1] "3_0_4"
# [1] "3_0_5"
# [1] "3_0_6"
# [1] "3_0_7"
# [1] "3_0_8"
# [1] "3_0_9"
# [1] "3_0_10"
# [1] "4_0_0"
# [1] "4_0_1"
# [1] "4_0_2"
# [1] "4_0_3"
# [1] "4_0_4"
# [1] "4_0_5"
# [1] "4_0_6"
# [1] "4_0_7"
# [1] "4_0_8"
# [1] "4_0_9"
# [1] "4_0_10"
# [1] "5_0_0"
# [1] "5_0_1"
# [1] "5_0_2"
# [1] "5_0_3"
# [1] "5_0_4"
# [1] "5_0_5"
# [1] "5_0_6"
# [1] "5_0_7"
# [1] "5_0_8"
# [1] "5_0_9"
# [1] "5_0_10"
# [1] "6_0_0"
# [1] "6_0_1"
# [1] "6_0_2"
# [1] "6_0_3"
# [1] "6_0_4"
# [1] "6_0_5"
# [1] "6_0_6"
# [1] "6_0_7"
# [1] "6_0_8"
# [1] "6_0_9"
# [1] "6_0_10"
# [1] "7_0_0"
# [1] "7_0_1"
# [1] "7_0_2"
# [1] "7_0_3"
# [1] "7_0_4"
# [1] "7_0_5"
# [1] "7_0_6"
# [1] "7_0_7"
# [1] "7_0_8"
# [1] "7_0_9"
# [1] "7_0_10"
# [1] "8_0_0"
# [1] "8_0_1"
# [1] "8_0_2"
# [1] "8_0_3"
# [1] "8_0_4"
# [1] "8_0_5"
# [1] "8_0_6"
# [1] "8_0_7"
# [1] "8_0_8"
# [1] "8_0_9"
# [1] "8_0_10"
# [1] "9_0_0"
# [1] "9_0_1"
# [1] "9_0_2"
# [1] "9_0_3"
# [1] "9_0_4"
# [1] "9_0_5"
# [1] "9_0_6"
# [1] "9_0_7"
# [1] "9_0_8"
# [1] "9_0_9"
# [1] "9_0_10"
# [1] "10_0_0"
# [1] "10_0_1"
# [1] "10_0_2"
# [1] "10_0_3"
# [1] "10_0_4"
# [1] "10_0_5"
# [1] "10_0_6"
# [1] "10_0_7"
# [1] "10_0_8"
# [1] "10_0_9"
# [1] "10_0_10"

# %%
head(custom_ARIMA_results[order(custom_ARIMA_results$model_AIC),],5)

head(custom_ARIMA_results[order(custom_ARIMA_results$model_BIC),],5)
# Out:
#    model_config model_AIC model_BIC Ljung_Box_pval RMSE
# 25 2,0,2        -6619.924 -6593.971 0.8801         0
# 36 3,0,2        -6618.770 -6587.626 0.9694         0
# 26 2,0,3        -6618.710 -6587.566 0.9692         0
# 47 4,0,2        -6616.978 -6580.644 0.9447         0
# 27 2,0,4        -6616.932 -6580.598 0.9385         0
#    model_config model_AIC model_BIC Ljung_Box_pval RMSE
# 1  0,0,0        -6607.626 -6602.435 0.05843        0
# 2  0,0,1        -6610.337 -6599.956 0.08985        0
# 12 1,0,0        -6609.990 -6599.608 0.08249        0
# 23 2,0,0        -6610.231 -6594.659 0.11550        0
# 3  0,0,2        -6609.571 -6593.999 0.09953        0

# %%
auto.arima(BABA_logret)
# Out:
# Series: BABA_logret
# ARIMA(2,0,3) with zero mean
#
# Coefficients:
#           ar1      ar2     ma1     ma2      ma3
#       -0.8706  -0.6276  0.9366  0.6474  -0.0422
# s.e.   0.1394   0.1962  0.1406  0.2100   0.0403
#
# sigma^2 estimated as 0.0003973:  log likelihood=3315.36
# AIC=-6618.71   AICc=-6618.65   BIC=-6587.57

# %% [markdown]
# # Conditional volatility

# %% [markdown]
# We can see that mean is very close to 0 (we might have white noise processes), and since we reject homoskedasticity in both subsamples, it is appropriate to fit model from GARCH family.
#
# We start with GARCH(1,1) and set last 200 observations to be kept for out of sample forecasting

# %%
garch11_spec = ugarchspec(mean.model = list(armaOrder=c(0, 0)), variance.model = list(model = "sGARCH", garchOrder = c(1, 1)))

garch11_s1 = ugarchfit(garch11_spec, INTC_s1_logret, out.sample = 200)
garch11_s2 = ugarchfit(garch11_spec, INTC_s2_logret, out.sample = 200)

garch11_s1
garch11_s2
# Out:
# *---------------------------------*
# *          GARCH Model Fit        *
# *---------------------------------*
#
# Conditional Variance Dynamics
# -----------------------------------
# GARCH Model	: sGARCH(1,1)
# Mean Model	: ARFIMA(0,0,0)
# Distribution	: norm
#
# Optimal Parameters
# ------------------------------------
#         Estimate  Std. Error  t value Pr(>|t|)
# mu      0.000344    0.000426  0.80679  0.41979
# omega   0.000009    0.000000 21.33250  0.00000
# alpha1  0.051978    0.005350  9.71588  0.00000
# beta1   0.908142    0.009337 97.26158  0.00000
#
# Robust Standard Errors:
#         Estimate  Std. Error  t value Pr(>|t|)
# mu      0.000344    0.000426  0.80691  0.41972
# omega   0.000009    0.000001 15.16252  0.00000
# alpha1  0.051978    0.004196 12.38593  0.00000
# beta1   0.908142    0.010701 84.86830  0.00000
#
# LogLikelihood : 2980.027
#
# Information Criteria
# ------------------------------------
#
# Akaike       -5.6311
# Bayes        -5.6123
# Shibata      -5.6311
# Hannan-Quinn -5.6240
#
# Weighted Ljung-Box Test on Standardized Residuals
# ------------------------------------
#                         statistic p-value
# Lag[1]                    0.05423  0.8159
# Lag[2*(p+q)+(p+q)-1][2]   0.06557  0.9445
# Lag[4*(p+q)+(p+q)-1][5]   0.63482  0.9350
# d.o.f=0
# H0 : No serial correlation
#
# Weighted Ljung-Box Test on Standardized Squared Residuals
# ------------------------------------
#                         statistic p-value
# Lag[1]                    0.01175  0.9137
# Lag[2*(p+q)+(p+q)-1][5]   0.56977  0.9464
# Lag[4*(p+q)+(p+q)-1][9]   1.51418  0.9544
# d.o.f=2
#
# Weighted ARCH LM Tests
# ------------------------------------
#             Statistic Shape Scale P-Value
# ARCH Lag[3]    0.7619 0.500 2.000  0.3827
# ARCH Lag[5]    0.9201 1.440 1.667  0.7568
# ARCH Lag[7]    1.8343 2.315 1.543  0.7523
#
# Nyblom stability test
# ------------------------------------
# Joint Statistic:  26.6868
# Individual Statistics:
# mu     0.05646
# omega  2.33608
# alpha1 0.26398
# beta1  0.18327
#
# Asymptotic Critical Values (10% 5% 1%)
# Joint Statistic:     	 1.07 1.24 1.6
# Individual Statistic:	 0.35 0.47 0.75
#
# Sign Bias Test
# ------------------------------------
#                    t-value   prob sig
# Sign Bias           0.2407 0.8098
# Negative Sign Bias  0.3973 0.6912
# Positive Sign Bias  0.9542 0.3402
# Joint Effect        1.5736 0.6654
#
#
# Adjusted Pearson Goodness-of-Fit Test:
# ------------------------------------
#   group statistic p-value(g-1)
# 1    20     27.18      0.10049
# 2    30     40.74      0.07256
# 3    40     53.43      0.06176
# 4    50     53.45      0.30717
#
#
# Elapsed time : 0.111851
# *---------------------------------*
# *          GARCH Model Fit        *
# *---------------------------------*
#
# Conditional Variance Dynamics
# -----------------------------------
# GARCH Model	: sGARCH(1,1)
# Mean Model	: ARFIMA(0,0,0)
# Distribution	: norm
#
# Optimal Parameters
# ------------------------------------
#         Estimate  Std. Error   t value Pr(>|t|)
# mu      0.000205    0.000458   0.44665  0.65513
# omega   0.000003    0.000002   1.42977  0.15278
# alpha1  0.031419    0.006205   5.06356  0.00000
# beta1   0.959896    0.007087 135.44346  0.00000
#
# Robust Standard Errors:
#         Estimate  Std. Error  t value Pr(>|t|)
# mu      0.000205    0.000506  0.40459  0.68578
# omega   0.000003    0.000014  0.19153  0.84811
# alpha1  0.031419    0.013774  2.28097  0.02255
# beta1   0.959896    0.032207 29.80393  0.00000
#
# LogLikelihood : 2797.8
#
# Information Criteria
# ------------------------------------
#
# Akaike       -5.5050
# Bayes        -5.4856
# Shibata      -5.5051
# Hannan-Quinn -5.4977
#
# Weighted Ljung-Box Test on Standardized Residuals
# ------------------------------------
#                         statistic p-value
# Lag[1]                      1.619  0.2032
# Lag[2*(p+q)+(p+q)-1][2]     1.641  0.3299
# Lag[4*(p+q)+(p+q)-1][5]     2.145  0.5845
# d.o.f=0
# H0 : No serial correlation
#
# Weighted Ljung-Box Test on Standardized Squared Residuals
# ------------------------------------
#                         statistic p-value
# Lag[1]                     0.2256  0.6348
# Lag[2*(p+q)+(p+q)-1][5]    0.2959  0.9841
# Lag[4*(p+q)+(p+q)-1][9]    0.8184  0.9926
# d.o.f=2
#
# Weighted ARCH LM Tests
# ------------------------------------
#             Statistic Shape Scale P-Value
# ARCH Lag[3]   0.01761 0.500 2.000  0.8944
# ARCH Lag[5]   0.17276 1.440 1.667  0.9718
# ARCH Lag[7]   0.34075 2.315 1.543  0.9905
#
# Nyblom stability test
# ------------------------------------
# Joint Statistic:  3.7424
# Individual Statistics:
# mu     0.0777
# omega  1.0775
# alpha1 0.2275
# beta1  0.2562
#
# Asymptotic Critical Values (10% 5% 1%)
# Joint Statistic:     	 1.07 1.24 1.6
# Individual Statistic:	 0.35 0.47 0.75
#
# Sign Bias Test
# ------------------------------------
#                    t-value   prob sig
# Sign Bias           0.9690 0.3328
# Negative Sign Bias  0.7407 0.4591
# Positive Sign Bias  1.6259 0.1043
# Joint Effect        3.8256 0.2809
#
#
# Adjusted Pearson Goodness-of-Fit Test:
# ------------------------------------
#   group statistic p-value(g-1)
# 1    20     61.95    1.897e-06
# 2    30     76.85    3.314e-06
# 3    40     90.62    5.462e-06
# 4    50     94.51    1.024e-04
#
#
# Elapsed time : 0.07993197

# %% [markdown]
# From the results we can see that all coefficients except mean are significant on both subsamples and null hypothesis of no autocorellation cannot be rejected (Ljung Box test).

# %% [markdown]
# From test for normality we get

# %%
jarque.bera.test(residuals(garch11_s1))

par(mfrow = c(1, 2))

hist(residuals(garch11_s1), breaks = 30, main ='Histogram', cex.main = 0.8, cex.lab = 0.8, xlab = NA,
    cex.axis = 0.8)
box()

qqnorm(residuals(garch11_s1), cex.main = 0.8, cex.lab = 0.8, cex.axis = 0.8) 
qqline(residuals(garch11_s1), lwd = 2)
# Out:
# 	Jarque Bera Test
#
# data:  residuals(garch11_s1)
# X-squared = 116.05, df = 2, p-value < 2.2e-16
# Plot with title "Normal Q-Q Plot"

# %%
jarque.bera.test(residuals(garch11_s2))

par(mfrow = c(1, 2))

hist(residuals(garch11_s2), breaks = 30, main ='Histogram', cex.main = 0.8, cex.lab = 0.8, xlab = NA,
    cex.axis = 0.8)
box()

qqnorm(residuals(garch11_s2), cex.main = 0.8, cex.lab = 0.8, cex.axis = 0.8) 
qqline(residuals(garch11_s2), lwd = 2)
# Out:
# 	Jarque Bera Test
#
# data:  residuals(garch11_s2)
# X-squared = 1054.7, df = 2, p-value < 2.2e-16
# Plot with title "Normal Q-Q Plot"

# %% [markdown]
# residuals do not appear to be normally distributed, lets fit residuals having students t-distribution

# %%
garch11t_spec = ugarchspec(mean.model = list(armaOrder=c(0, 0)), variance.model = list(model = "sGARCH", garchOrder = c(1, 1)),distribution.model = 'std')

garch11t_s1 = ugarchfit(garch11t_spec, INTC_s1_logret, out.sample = 200)
garch11t_s2 = ugarchfit(garch11t_spec, INTC_s2_logret, out.sample = 200)

garch11t_s1
garch11t_s2
# Out:
# *---------------------------------*
# *          GARCH Model Fit        *
# *---------------------------------*
#
# Conditional Variance Dynamics
# -----------------------------------
# GARCH Model	: sGARCH(1,1)
# Mean Model	: ARFIMA(0,0,0)
# Distribution	: std
#
# Optimal Parameters
# ------------------------------------
#         Estimate  Std. Error  t value Pr(>|t|)
# mu      0.000379    0.000396  0.95860 0.337762
# omega   0.000005    0.000007  0.66768 0.504336
# alpha1  0.058325    0.016824  3.46685 0.000527
# beta1   0.920739    0.025964 35.46231 0.000000
# shape   6.331080    1.247691  5.07424 0.000000
#
# Robust Standard Errors:
#         Estimate  Std. Error  t value Pr(>|t|)
# mu      0.000379    0.000374  1.01277 0.311171
# omega   0.000005    0.000032  0.15142 0.879644
# alpha1  0.058325    0.029785  1.95824 0.050202
# beta1   0.920739    0.087757 10.49192 0.000000
# shape   6.331080    2.337860  2.70807 0.006768
#
# LogLikelihood : 3006.959
#
# Information Criteria
# ------------------------------------
#
# Akaike       -5.6801
# Bayes        -5.6567
# Shibata      -5.6802
# Hannan-Quinn -5.6713
#
# Weighted Ljung-Box Test on Standardized Residuals
# ------------------------------------
#                         statistic p-value
# Lag[1]                    0.07539  0.7836
# Lag[2*(p+q)+(p+q)-1][2]   0.07573  0.9370
# Lag[4*(p+q)+(p+q)-1][5]   0.60998  0.9395
# d.o.f=0
# H0 : No serial correlation
#
# Weighted Ljung-Box Test on Standardized Squared Residuals
# ------------------------------------
#                         statistic p-value
# Lag[1]                    0.07808  0.7799
# Lag[2*(p+q)+(p+q)-1][5]   0.76405  0.9103
# Lag[4*(p+q)+(p+q)-1][9]   1.71835  0.9358
# d.o.f=2
#
# Weighted ARCH LM Tests
# ------------------------------------
#             Statistic Shape Scale P-Value
# ARCH Lag[3]     0.876 0.500 2.000  0.3493
# ARCH Lag[5]     1.259 1.440 1.667  0.6578
# ARCH Lag[7]     1.996 2.315 1.543  0.7182
#
# Nyblom stability test
# ------------------------------------
# Joint Statistic:  1.8027
# Individual Statistics:
# mu     0.03122
# omega  0.13501
# alpha1 0.52708
# beta1  0.39687
# shape  0.92961
#
# Asymptotic Critical Values (10% 5% 1%)
# Joint Statistic:     	 1.28 1.47 1.88
# Individual Statistic:	 0.35 0.47 0.75
#
# Sign Bias Test
# ------------------------------------
#                    t-value   prob sig
# Sign Bias           0.1600 0.8729
# Negative Sign Bias  0.5360 0.5920
# Positive Sign Bias  0.8094 0.4185
# Joint Effect        1.6366 0.6511
#
#
# Adjusted Pearson Goodness-of-Fit Test:
# ------------------------------------
#   group statistic p-value(g-1)
# 1    20     14.24       0.7696
# 2    30     11.28       0.9987
# 3    40     27.24       0.9219
# 4    50     34.06       0.9483
#
#
# Elapsed time : 0.139812
# *---------------------------------*
# *          GARCH Model Fit        *
# *---------------------------------*
#
# Conditional Variance Dynamics
# -----------------------------------
# GARCH Model	: sGARCH(1,1)
# Mean Model	: ARFIMA(0,0,0)
# Distribution	: std
#
# Optimal Parameters
# ------------------------------------
#         Estimate  Std. Error   t value Pr(>|t|)
# mu      0.000633    0.000375   1.68695 0.091614
# omega   0.000001    0.000002   0.41993 0.674534
# alpha1  0.035919    0.009555   3.75923 0.000170
# beta1   0.963081    0.008420 114.38683 0.000000
# shape   4.310570    0.231099  18.65250 0.000000
#
# Robust Standard Errors:
#         Estimate  Std. Error   t value Pr(>|t|)
# mu      0.000633    0.000437  1.447941 0.147634
# omega   0.000001    0.000010  0.083478 0.933472
# alpha1  0.035919    0.058403  0.615012 0.538547
# beta1   0.963081    0.051814 18.587237 0.000000
# shape   4.310570    2.498811  1.725048 0.084519
#
# LogLikelihood : 2876.723
#
# Information Criteria
# ------------------------------------
#
# Akaike       -5.6586
# Bayes        -5.6343
# Shibata      -5.6586
# Hannan-Quinn -5.6494
#
# Weighted Ljung-Box Test on Standardized Residuals
# ------------------------------------
#                         statistic p-value
# Lag[1]                      1.144  0.2847
# Lag[2*(p+q)+(p+q)-1][2]     1.186  0.4417
# Lag[4*(p+q)+(p+q)-1][5]     1.686  0.6941
# d.o.f=0
# H0 : No serial correlation
#
# Weighted Ljung-Box Test on Standardized Squared Residuals
# ------------------------------------
#                         statistic p-value
# Lag[1]                     0.2140  0.6436
# Lag[2*(p+q)+(p+q)-1][5]    0.2650  0.9872
# Lag[4*(p+q)+(p+q)-1][9]    0.7505  0.9943
# d.o.f=2
#
# Weighted ARCH LM Tests
# ------------------------------------
#             Statistic Shape Scale P-Value
# ARCH Lag[3] 0.0001246 0.500 2.000  0.9911
# ARCH Lag[5] 0.1483086 1.440 1.667  0.9772
# ARCH Lag[7] 0.2793606 2.315 1.543  0.9938
#
# Nyblom stability test
# ------------------------------------
# Joint Statistic:  102.3805
# Individual Statistics:
# mu      0.1350
# omega  14.9508
# alpha1  0.2035
# beta1   0.1812
# shape   0.3420
#
# Asymptotic Critical Values (10% 5% 1%)
# Joint Statistic:     	 1.28 1.47 1.88
# Individual Statistic:	 0.35 0.47 0.75
#
# Sign Bias Test
# ------------------------------------
#                    t-value   prob sig
# Sign Bias           0.5159 0.6060
# Negative Sign Bias  0.5690 0.5695
# Positive Sign Bias  1.3173 0.1880
# Joint Effect        2.1015 0.5516
#
#
# Adjusted Pearson Goodness-of-Fit Test:
# ------------------------------------
#   group statistic p-value(g-1)
# 1    20     11.94       0.8883
# 2    30     18.27       0.9386
# 3    40     38.52       0.4917
# 4    50     35.49       0.9259
#
#
# Elapsed time : 0.1278598

# %%
jarque.bera.test(residuals(garch11t_s1))

par(mfrow = c(1, 2))

hist(residuals(garch11t_s1), breaks = 30, main ='Histogram', cex.main = 0.8, cex.lab = 0.8, xlab = NA,
    cex.axis = 0.8)
box()

qqnorm(residuals(garch11t_s1), cex.main = 0.8, cex.lab = 0.8, cex.axis = 0.8) 
qqline(residuals(garch11t_s1), lwd = 2)
# Out:
# 	Jarque Bera Test
#
# data:  residuals(garch11t_s1)
# X-squared = 116.05, df = 2, p-value < 2.2e-16
# Plot with title "Normal Q-Q Plot"

# %%
jarque.bera.test(residuals(garch11t_s2))

par(mfrow = c(1, 2))

hist(residuals(garch11t_s2), breaks = 30, main ='Histogram', cex.main = 0.8, cex.lab = 0.8, xlab = NA,
    cex.axis = 0.8)
box()

qqnorm(residuals(garch11t_s2), cex.main = 0.8, cex.lab = 0.8, cex.axis = 0.8) 
qqline(residuals(garch11t_s2), lwd = 2)
# Out:
# 	Jarque Bera Test
#
# data:  residuals(garch11t_s2)
# X-squared = 1054.7, df = 2, p-value < 2.2e-16
# Plot with title "Normal Q-Q Plot"

# %% [markdown]
# We can see that there is no significant improvement.

# %% [markdown]
# Lets try to fit GARCH that accounts for asymmetric responses, namely EGEARCH and GJRGARCH

# %%
egearch_spec <- ugarchspec(mean.model = list(armaOrder=c(0, 0)), variance.model = list(model = "eGARCH", 
                      garchOrder = c(1, 1)))


egearch_s1 = ugarchfit(egearch_spec, INTC_s1_logret, out.sample = 200)
egearch_s2 = ugarchfit(egearch_spec, INTC_s2_logret, out.sample = 200)

egearch_s1
egearch_s2
# Out:
# *---------------------------------*
# *          GARCH Model Fit        *
# *---------------------------------*
#
# Conditional Variance Dynamics
# -----------------------------------
# GARCH Model	: eGARCH(1,1)
# Mean Model	: ARFIMA(0,0,0)
# Distribution	: norm
#
# Optimal Parameters
# ------------------------------------
#         Estimate  Std. Error   t value Pr(>|t|)
# mu      0.000188    0.000426   0.44016 0.659818
# omega  -0.348616    0.044738  -7.79242 0.000000
# alpha1 -0.028390    0.018041  -1.57366 0.115567
# beta1   0.958435    0.005335 179.64853 0.000000
# gamma1  0.115799    0.024816   4.66624 0.000003
#
# Robust Standard Errors:
#         Estimate  Std. Error   t value Pr(>|t|)
# mu      0.000188    0.000381   0.49217 0.622601
# omega  -0.348616    0.021826 -15.97271 0.000000
# alpha1 -0.028390    0.028781  -0.98641 0.323934
# beta1   0.958435    0.002409 397.83113 0.000000
# gamma1  0.115799    0.032012   3.61737 0.000298
#
# LogLikelihood : 2985.236
#
# Information Criteria
# ------------------------------------
#
# Akaike       -5.6390
# Bayes        -5.6156
# Shibata      -5.6391
# Hannan-Quinn -5.6301
#
# Weighted Ljung-Box Test on Standardized Residuals
# ------------------------------------
#                         statistic p-value
# Lag[1]                    0.02580  0.8724
# Lag[2*(p+q)+(p+q)-1][2]   0.03231  0.9704
# Lag[4*(p+q)+(p+q)-1][5]   0.50797  0.9564
# d.o.f=0
# H0 : No serial correlation
#
# Weighted Ljung-Box Test on Standardized Squared Residuals
# ------------------------------------
#                         statistic p-value
# Lag[1]                     0.1206  0.7284
# Lag[2*(p+q)+(p+q)-1][5]    0.7016  0.9226
# Lag[4*(p+q)+(p+q)-1][9]    1.7065  0.9370
# d.o.f=2
#
# Weighted ARCH LM Tests
# ------------------------------------
#             Statistic Shape Scale P-Value
# ARCH Lag[3]    0.4984 0.500 2.000  0.4802
# ARCH Lag[5]    0.9984 1.440 1.667  0.7334
# ARCH Lag[7]    1.9333 2.315 1.543  0.7315
#
# Nyblom stability test
# ------------------------------------
# Joint Statistic:  0.9541
# Individual Statistics:
# mu     0.06334
# omega  0.09386
# alpha1 0.50675
# beta1  0.08835
# gamma1 0.05582
#
# Asymptotic Critical Values (10% 5% 1%)
# Joint Statistic:     	 1.28 1.47 1.88
# Individual Statistic:	 0.35 0.47 0.75
#
# Sign Bias Test
# ------------------------------------
#                    t-value   prob sig
# Sign Bias           0.2520 0.8011
# Negative Sign Bias  0.5795 0.5624
# Positive Sign Bias  1.1681 0.2430
# Joint Effect        2.7348 0.4343
#
#
# Adjusted Pearson Goodness-of-Fit Test:
# ------------------------------------
#   group statistic p-value(g-1)
# 1    20     23.78      0.20489
# 2    30     40.28      0.07939
# 3    40     50.32      0.10576
# 4    50     59.04      0.15430
#
#
# Elapsed time : 0.175766
# *---------------------------------*
# *          GARCH Model Fit        *
# *---------------------------------*
#
# Conditional Variance Dynamics
# -----------------------------------
# GARCH Model	: eGARCH(1,1)
# Mean Model	: ARFIMA(0,0,0)
# Distribution	: norm
#
# Optimal Parameters
# ------------------------------------
#         Estimate  Std. Error   t value Pr(>|t|)
# mu      0.000356    0.000452   0.78788  0.43077
# omega  -0.144553    0.010073 -14.35124  0.00000
# alpha1  0.004071    0.014962   0.27207  0.78557
# beta1   0.981648    0.001191 823.98074  0.00000
# gamma1  0.104403    0.019465   5.36357  0.00000
#
# Robust Standard Errors:
#         Estimate  Std. Error    t value Pr(>|t|)
# mu      0.000356    0.000440    0.80971 0.418106
# omega  -0.144553    0.007432  -19.45036 0.000000
# alpha1  0.004071    0.030136    0.13508 0.892552
# beta1   0.981648    0.000964 1018.30835 0.000000
# gamma1  0.104403    0.034136    3.05839 0.002225
#
# LogLikelihood : 2806.28
#
# Information Criteria
# ------------------------------------
#
# Akaike       -5.5198
# Bayes        -5.4955
# Shibata      -5.5198
# Hannan-Quinn -5.5106
#
# Weighted Ljung-Box Test on Standardized Residuals
# ------------------------------------
#                         statistic p-value
# Lag[1]                      1.366  0.2425
# Lag[2*(p+q)+(p+q)-1][2]     1.367  0.3932
# Lag[4*(p+q)+(p+q)-1][5]     1.936  0.6337
# d.o.f=0
# H0 : No serial correlation
#
# Weighted Ljung-Box Test on Standardized Squared Residuals
# ------------------------------------
#                         statistic p-value
# Lag[1]                     0.1613  0.6879
# Lag[2*(p+q)+(p+q)-1][5]    0.2177  0.9912
# Lag[4*(p+q)+(p+q)-1][9]    0.8532  0.9915
# d.o.f=2
#
# Weighted ARCH LM Tests
# ------------------------------------
#             Statistic Shape Scale P-Value
# ARCH Lag[3]  0.004015 0.500 2.000  0.9495
# ARCH Lag[5]  0.154681 1.440 1.667  0.9758
# ARCH Lag[7]  0.366056 2.315 1.543  0.9889
#
# Nyblom stability test
# ------------------------------------
# Joint Statistic:  1.4585
# Individual Statistics:
# mu     0.04488
# omega  0.26284
# alpha1 0.20714
# beta1  0.24949
# gamma1 0.19889
#
# Asymptotic Critical Values (10% 5% 1%)
# Joint Statistic:     	 1.28 1.47 1.88
# Individual Statistic:	 0.35 0.47 0.75
#
# Sign Bias Test
# ------------------------------------
#                    t-value   prob sig
# Sign Bias           0.9153 0.3603
# Negative Sign Bias  0.5978 0.5501
# Positive Sign Bias  1.3192 0.1874
# Joint Effect        2.7178 0.4372
#
#
# Adjusted Pearson Goodness-of-Fit Test:
# ------------------------------------
#   group statistic p-value(g-1)
# 1    20     57.77    8.676e-06
# 2    30     61.31    4.238e-04
# 3    40     78.48    1.823e-04
# 4    50     84.95    1.099e-03
#
#
# Elapsed time : 0.199744

# %% [markdown]
# and EGEARCH with t dstribution

# %%
egearcht_spec <- ugarchspec(mean.model = list(armaOrder=c(0, 0)), variance.model = list(model = "eGARCH", 
                      garchOrder = c(1, 1)),distribution.model = 'std')


egearcht_s1 = ugarchfit(egearcht_spec, INTC_s1_logret, out.sample = 200)
egearcht_s2 = ugarchfit(egearcht_spec, INTC_s2_logret, out.sample = 200)

egearcht_s1
egearcht_s2
# Out:
# *---------------------------------*
# *          GARCH Model Fit        *
# *---------------------------------*
#
# Conditional Variance Dynamics
# -----------------------------------
# GARCH Model	: eGARCH(1,1)
# Mean Model	: ARFIMA(0,0,0)
# Distribution	: std
#
# Optimal Parameters
# ------------------------------------
#         Estimate  Std. Error   t value Pr(>|t|)
# mu      0.000252    0.000388   0.65054 0.515343
# omega  -0.254164    0.028583  -8.89222 0.000000
# alpha1 -0.040164    0.020844  -1.92687 0.053996
# beta1   0.970193    0.003401 285.28818 0.000000
# gamma1  0.131928    0.053511   2.46544 0.013685
# shape   6.633858    0.998678   6.64264 0.000000
#
# Robust Standard Errors:
#         Estimate  Std. Error  t value Pr(>|t|)
# mu      0.000252    0.000391   0.6456 0.518536
# omega  -0.254164    0.056827  -4.4726 0.000008
# alpha1 -0.040164    0.023094  -1.7392 0.082004
# beta1   0.970193    0.006601 146.9761 0.000000
# gamma1  0.131928    0.092345   1.4286 0.153106
# shape   6.633858    1.840988   3.6034 0.000314
#
# LogLikelihood : 3011.157
#
# Information Criteria
# ------------------------------------
#
# Akaike       -5.6862
# Bayes        -5.6580
# Shibata      -5.6863
# Hannan-Quinn -5.6755
#
# Weighted Ljung-Box Test on Standardized Residuals
# ------------------------------------
#                         statistic p-value
# Lag[1]                    0.03790  0.8457
# Lag[2*(p+q)+(p+q)-1][2]   0.03847  0.9654
# Lag[4*(p+q)+(p+q)-1][5]   0.46694  0.9627
# d.o.f=0
# H0 : No serial correlation
#
# Weighted Ljung-Box Test on Standardized Squared Residuals
# ------------------------------------
#                         statistic p-value
# Lag[1]                     0.3726  0.5416
# Lag[2*(p+q)+(p+q)-1][5]    1.1544  0.8239
# Lag[4*(p+q)+(p+q)-1][9]    2.2175  0.8775
# d.o.f=2
#
# Weighted ARCH LM Tests
# ------------------------------------
#             Statistic Shape Scale P-Value
# ARCH Lag[3]    0.5973 0.500 2.000  0.4396
# ARCH Lag[5]    1.5244 1.440 1.667  0.5859
# ARCH Lag[7]    2.3125 2.315 1.543  0.6513
#
# Nyblom stability test
# ------------------------------------
# Joint Statistic:  1.381
# Individual Statistics:
# mu     0.04013
# omega  0.34400
# alpha1 0.24678
# beta1  0.33739
# gamma1 0.16401
# shape  0.83481
#
# Asymptotic Critical Values (10% 5% 1%)
# Joint Statistic:     	 1.49 1.68 2.12
# Individual Statistic:	 0.35 0.47 0.75
#
# Sign Bias Test
# ------------------------------------
#                    t-value   prob sig
# Sign Bias           0.3115 0.7555
# Negative Sign Bias  0.8451 0.3982
# Positive Sign Bias  1.1987 0.2309
# Joint Effect        3.5037 0.3203
#
#
# Adjusted Pearson Goodness-of-Fit Test:
# ------------------------------------
#   group statistic p-value(g-1)
# 1    20     20.45       0.3682
# 2    30     28.14       0.5106
# 3    40     32.91       0.7428
# 4    50     42.20       0.7434
#
#
# Elapsed time : 0.263696
# *---------------------------------*
# *          GARCH Model Fit        *
# *---------------------------------*
#
# Conditional Variance Dynamics
# -----------------------------------
# GARCH Model	: eGARCH(1,1)
# Mean Model	: ARFIMA(0,0,0)
# Distribution	: std
#
# Optimal Parameters
# ------------------------------------
#         Estimate  Std. Error  t value Pr(>|t|)
# mu      0.000653    0.000569   1.1478 0.251060
# omega  -0.095488    0.016833  -5.6726 0.000000
# alpha1 -0.024928    0.019469  -1.2804 0.200395
# beta1   0.988666    0.002088 473.4426 0.000000
# gamma1  0.128994    0.045988   2.8050 0.005032
# shape   4.282157    0.571732   7.4898 0.000000
#
# Robust Standard Errors:
#         Estimate  Std. Error   t value Pr(>|t|)
# mu      0.000653    0.000912   0.71636 0.473771
# omega  -0.095488    0.021485  -4.44450 0.000009
# alpha1 -0.024928    0.021446  -1.16239 0.245078
# beta1   0.988666    0.002808 352.12833 0.000000
# gamma1  0.128994    0.076407   1.68825 0.091363
# shape   4.282157    0.628022   6.81848 0.000000
#
# LogLikelihood : 2881.248
#
# Information Criteria
# ------------------------------------
#
# Akaike       -5.6655
# Bayes        -5.6364
# Shibata      -5.6656
# Hannan-Quinn -5.6545
#
# Weighted Ljung-Box Test on Standardized Residuals
# ------------------------------------
#                         statistic p-value
# Lag[1]                     0.7469  0.3875
# Lag[2*(p+q)+(p+q)-1][2]    0.7489  0.5874
# Lag[4*(p+q)+(p+q)-1][5]    1.3986  0.7648
# d.o.f=0
# H0 : No serial correlation
#
# Weighted Ljung-Box Test on Standardized Squared Residuals
# ------------------------------------
#                         statistic p-value
# Lag[1]                     0.1985  0.6559
# Lag[2*(p+q)+(p+q)-1][5]    0.2471  0.9888
# Lag[4*(p+q)+(p+q)-1][9]    0.8408  0.9919
# d.o.f=2
#
# Weighted ARCH LM Tests
# ------------------------------------
#             Statistic Shape Scale P-Value
# ARCH Lag[3]  0.004379 0.500 2.000  0.9472
# ARCH Lag[5]  0.136655 1.440 1.667  0.9796
# ARCH Lag[7]  0.358190 2.315 1.543  0.9894
#
# Nyblom stability test
# ------------------------------------
# Joint Statistic:  1.1518
# Individual Statistics:
# mu     0.1163
# omega  0.1672
# alpha1 0.2853
# beta1  0.1616
# gamma1 0.1087
# shape  0.2855
#
# Asymptotic Critical Values (10% 5% 1%)
# Joint Statistic:     	 1.49 1.68 2.12
# Individual Statistic:	 0.35 0.47 0.75
#
# Sign Bias Test
# ------------------------------------
#                    t-value   prob sig
# Sign Bias            0.530 0.5962
# Negative Sign Bias   0.143 0.8863
# Positive Sign Bias   1.052 0.2930
# Joint Effect         1.139 0.7677
#
#
# Adjusted Pearson Goodness-of-Fit Test:
# ------------------------------------
#   group statistic p-value(g-1)
# 1    20     12.96       0.8406
# 2    30     26.31       0.6089
# 3    40     35.76       0.6185
# 4    50     45.34       0.6221
#
#
# Elapsed time : 0.2636812

# %% [markdown]
# and GJR_GARCH (both with normal and t distribution)

# %%
gjrgarch_spec <- ugarchspec(mean.model = list(armaOrder=c(0, 0)), variance.model = list(model = "gjrGARCH", 
                      garchOrder = c(1, 1)))
gjrgarcht_spec <- ugarchspec(mean.model = list(armaOrder=c(0, 0)), variance.model = list(model = "gjrGARCH", 
                      garchOrder = c(1, 1)),distribution.model = 'std')

gjrgarch_s1 = ugarchfit(gjrgarch_spec, INTC_s1_logret, out.sample = 200)
gjrgarch_s2 = ugarchfit(gjrgarch_spec, INTC_s2_logret, out.sample = 200)
gjrgarcht_s1 = ugarchfit(gjrgarcht_spec, INTC_s1_logret, out.sample = 200)
gjrgarcht_s2 = ugarchfit(gjrgarcht_spec, INTC_s2_logret, out.sample = 200)

gjrgarch_s1
gjrgarch_s2
gjrgarcht_s1
gjrgarcht_s2
# Out:
# *---------------------------------*
# *          GARCH Model Fit        *
# *---------------------------------*
#
# Conditional Variance Dynamics
# -----------------------------------
# GARCH Model	: gjrGARCH(1,1)
# Mean Model	: ARFIMA(0,0,0)
# Distribution	: norm
#
# Optimal Parameters
# ------------------------------------
#         Estimate  Std. Error  t value Pr(>|t|)
# mu      0.000286    0.000429  0.66712 0.504698
# omega   0.000009    0.000000 26.61261 0.000000
# alpha1  0.041330    0.010535  3.92291 0.000087
# beta1   0.906156    0.009223 98.24721 0.000000
# gamma1  0.020909    0.023274  0.89838 0.368984
#
# Robust Standard Errors:
#         Estimate  Std. Error  t value Pr(>|t|)
# mu      0.000286    0.000411  0.69703 0.485783
# omega   0.000009    0.000000 19.70860 0.000000
# alpha1  0.041330    0.016867  2.45028 0.014274
# beta1   0.906156    0.011533 78.57217 0.000000
# gamma1  0.020909    0.041268  0.50665 0.612398
#
# LogLikelihood : 2980.403
#
# Information Criteria
# ------------------------------------
#
# Akaike       -5.6299
# Bayes        -5.6064
# Shibata      -5.6299
# Hannan-Quinn -5.6210
#
# Weighted Ljung-Box Test on Standardized Residuals
# ------------------------------------
#                         statistic p-value
# Lag[1]                    0.04317  0.8354
# Lag[2*(p+q)+(p+q)-1][2]   0.05388  0.9533
# Lag[4*(p+q)+(p+q)-1][5]   0.59804  0.9416
# d.o.f=0
# H0 : No serial correlation
#
# Weighted Ljung-Box Test on Standardized Squared Residuals
# ------------------------------------
#                         statistic p-value
# Lag[1]                    0.03945  0.8426
# Lag[2*(p+q)+(p+q)-1][5]   0.63393  0.9352
# Lag[4*(p+q)+(p+q)-1][9]   1.60830  0.9462
# d.o.f=2
#
# Weighted ARCH LM Tests
# ------------------------------------
#             Statistic Shape Scale P-Value
# ARCH Lag[3]    0.7756 0.500 2.000  0.3785
# ARCH Lag[5]    1.0177 1.440 1.667  0.7277
# ARCH Lag[7]    1.9312 2.315 1.543  0.7319
#
# Nyblom stability test
# ------------------------------------
# Joint Statistic:  29.511
# Individual Statistics:
# mu     0.07061
# omega  2.61085
# alpha1 0.21552
# beta1  0.16539
# gamma1 0.62661
#
# Asymptotic Critical Values (10% 5% 1%)
# Joint Statistic:     	 1.28 1.47 1.88
# Individual Statistic:	 0.35 0.47 0.75
#
# Sign Bias Test
# ------------------------------------
#                    t-value   prob sig
# Sign Bias           0.2979 0.7658
# Negative Sign Bias  0.4935 0.6217
# Positive Sign Bias  1.1283 0.2595
# Joint Effect        2.2263 0.5268
#
#
# Adjusted Pearson Goodness-of-Fit Test:
# ------------------------------------
#   group statistic p-value(g-1)
# 1    20     30.02      0.05155
# 2    30     38.47      0.11227
# 3    40     58.42      0.02351
# 4    50     55.91      0.23127
#
#
# Elapsed time : 0.2778001
# *---------------------------------*
# *          GARCH Model Fit        *
# *---------------------------------*
#
# Conditional Variance Dynamics
# -----------------------------------
# GARCH Model	: gjrGARCH(1,1)
# Mean Model	: ARFIMA(0,0,0)
# Distribution	: norm
#
# Optimal Parameters
# ------------------------------------
#         Estimate  Std. Error    t value Pr(>|t|)
# mu      0.000245    0.000152    1.61722  0.10583
# omega   0.000000    0.000001    0.82457  0.40962
# alpha1  0.024115    0.003029    7.96077  0.00000
# beta1   0.990555    0.000146 6794.59183  0.00000
# gamma1 -0.031340    0.005607   -5.58956  0.00000
#
# Robust Standard Errors:
#         Estimate  Std. Error    t value Pr(>|t|)
# mu      0.000245    0.000452    0.54241 0.587535
# omega   0.000000    0.000006    0.07064 0.943684
# alpha1  0.024115    0.005843    4.12717 0.000037
# beta1   0.990555    0.000197 5029.35365 0.000000
# gamma1 -0.031340    0.011035   -2.84021 0.004508
#
# LogLikelihood : 2803.01
#
# Information Criteria
# ------------------------------------
#
# Akaike       -5.5133
# Bayes        -5.4891
# Shibata      -5.5134
# Hannan-Quinn -5.5041
#
# Weighted Ljung-Box Test on Standardized Residuals
# ------------------------------------
#                         statistic p-value
# Lag[1]                      3.456 0.06301
# Lag[2*(p+q)+(p+q)-1][2]     3.490 0.10345
# Lag[4*(p+q)+(p+q)-1][5]     4.020 0.25158
# d.o.f=0
# H0 : No serial correlation
#
# Weighted Ljung-Box Test on Standardized Squared Residuals
# ------------------------------------
#                         statistic p-value
# Lag[1]                      0.786  0.3753
# Lag[2*(p+q)+(p+q)-1][5]     1.678  0.6963
# Lag[4*(p+q)+(p+q)-1][9]     2.509  0.8364
# d.o.f=2
#
# Weighted ARCH LM Tests
# ------------------------------------
#             Statistic Shape Scale P-Value
# ARCH Lag[3]    0.4408 0.500 2.000  0.5067
# ARCH Lag[5]    0.8151 1.440 1.667  0.7885
# ARCH Lag[7]    1.1199 2.315 1.543  0.8933
#
# Nyblom stability test
# ------------------------------------
# Joint Statistic:  220.3078
# Individual Statistics:
# mu      0.1921
# omega  27.8452
# alpha1  0.1473
# beta1   0.1268
# gamma1  0.1808
#
# Asymptotic Critical Values (10% 5% 1%)
# Joint Statistic:     	 1.28 1.47 1.88
# Individual Statistic:	 0.35 0.47 0.75
#
# Sign Bias Test
# ------------------------------------
#                    t-value    prob sig
# Sign Bias           0.5804 0.56179
# Negative Sign Bias  1.5929 0.11150
# Positive Sign Bias  1.7104 0.08749   *
# Joint Effect        6.0969 0.10699
#
#
# Adjusted Pearson Goodness-of-Fit Test:
# ------------------------------------
#   group statistic p-value(g-1)
# 1    20     52.01    6.583e-05
# 2    30     64.91    1.457e-04
# 3    40     76.67    2.983e-04
# 4    50     92.34    1.790e-04
#
#
# Elapsed time : 0.237468
# *---------------------------------*
# *          GARCH Model Fit        *
# *---------------------------------*
#
# Conditional Variance Dynamics
# -----------------------------------
# GARCH Model	: gjrGARCH(1,1)
# Mean Model	: ARFIMA(0,0,0)
# Distribution	: std
#
# Optimal Parameters
# ------------------------------------
#         Estimate  Std. Error  t value Pr(>|t|)
# mu      0.000337    0.000396  0.85256  0.39390
# omega   0.000006    0.000004  1.54986  0.12118
# alpha1  0.046903    0.008910  5.26407  0.00000
# beta1   0.914509    0.014282 64.03312  0.00000
# gamma1  0.028352    0.026903  1.05385  0.29195
# shape   6.375667    1.065327  5.98470  0.00000
#
# Robust Standard Errors:
#         Estimate  Std. Error  t value Pr(>|t|)
# mu      0.000337    0.000377  0.89588 0.370317
# omega   0.000006    0.000008  0.73125 0.464630
# alpha1  0.046903    0.033505  1.39985 0.161558
# beta1   0.914509    0.023229 39.36973 0.000000
# gamma1  0.028352    0.043631  0.64981 0.515817
# shape   6.375667    1.521054  4.19161 0.000028
#
# LogLikelihood : 3007.416
#
# Information Criteria
# ------------------------------------
#
# Akaike       -5.6791
# Bayes        -5.6509
# Shibata      -5.6792
# Hannan-Quinn -5.6684
#
# Weighted Ljung-Box Test on Standardized Residuals
# ------------------------------------
#                         statistic p-value
# Lag[1]                    0.06349  0.8011
# Lag[2*(p+q)+(p+q)-1][2]   0.06354  0.9460
# Lag[4*(p+q)+(p+q)-1][5]   0.55076  0.9496
# d.o.f=0
# H0 : No serial correlation
#
# Weighted Ljung-Box Test on Standardized Squared Residuals
# ------------------------------------
#                         statistic p-value
# Lag[1]                     0.1622  0.6871
# Lag[2*(p+q)+(p+q)-1][5]    1.0019  0.8592
# Lag[4*(p+q)+(p+q)-1][9]    2.0389  0.9003
# d.o.f=2
#
# Weighted ARCH LM Tests
# ------------------------------------
#             Statistic Shape Scale P-Value
# ARCH Lag[3]    0.9793 0.500 2.000  0.3224
# ARCH Lag[5]    1.5712 1.440 1.667  0.5738
# ARCH Lag[7]    2.2902 2.315 1.543  0.6560
#
# Nyblom stability test
# ------------------------------------
# Joint Statistic:  1.9501
# Individual Statistics:
# mu     0.03357
# omega  0.43628
# alpha1 0.51238
# beta1  0.41483
# gamma1 0.82032
# shape  1.01555
#
# Asymptotic Critical Values (10% 5% 1%)
# Joint Statistic:     	 1.49 1.68 2.12
# Individual Statistic:	 0.35 0.47 0.75
#
# Sign Bias Test
# ------------------------------------
#                    t-value   prob sig
# Sign Bias           0.3662 0.7143
# Negative Sign Bias  0.7582 0.4485
# Positive Sign Bias  1.0807 0.2801
# Joint Effect        2.5788 0.4612
#
#
# Adjusted Pearson Goodness-of-Fit Test:
# ------------------------------------
#   group statistic p-value(g-1)
# 1    20     15.53       0.6886
# 2    30     26.15       0.6174
# 3    40     47.67       0.1607
# 4    50     50.81       0.4023
#
#
# Elapsed time : 0.4019239
# *---------------------------------*
# *          GARCH Model Fit        *
# *---------------------------------*
#
# Conditional Variance Dynamics
# -----------------------------------
# GARCH Model	: gjrGARCH(1,1)
# Mean Model	: ARFIMA(0,0,0)
# Distribution	: std
#
# Optimal Parameters
# ------------------------------------
#         Estimate  Std. Error   t value Pr(>|t|)
# mu      0.000641    0.000378   1.69672  0.08975
# omega   0.000001    0.000001   0.60351  0.54617
# alpha1  0.036760    0.007229   5.08491  0.00000
# beta1   0.965954    0.005919 163.18652  0.00000
# gamma1 -0.007427    0.014636  -0.50746  0.61183
# shape   4.353401    0.424915  10.24535  0.00000
#
# Robust Standard Errors:
#         Estimate  Std. Error  t value Pr(>|t|)
# mu      0.000641    0.000410  1.56408  0.11780
# omega   0.000001    0.000004  0.16620  0.86800
# alpha1  0.036760    0.025922  1.41809  0.15617
# beta1   0.965954    0.030824 31.33812  0.00000
# gamma1 -0.007427    0.023179 -0.32042  0.74865
# shape   4.353401    1.359136  3.20307  0.00136
#
# LogLikelihood : 2876.812
#
# Information Criteria
# ------------------------------------
#
# Akaike       -5.6568
# Bayes        -5.6277
# Shibata      -5.6568
# Hannan-Quinn -5.6457
#
# Weighted Ljung-Box Test on Standardized Residuals
# ------------------------------------
#                         statistic p-value
# Lag[1]                      1.305  0.2533
# Lag[2*(p+q)+(p+q)-1][2]     1.352  0.3969
# Lag[4*(p+q)+(p+q)-1][5]     1.819  0.6619
# d.o.f=0
# H0 : No serial correlation
#
# Weighted Ljung-Box Test on Standardized Squared Residuals
# ------------------------------------
#                         statistic p-value
# Lag[1]                     0.2348  0.6280
# Lag[2*(p+q)+(p+q)-1][5]    0.2877  0.9850
# Lag[4*(p+q)+(p+q)-1][9]    0.7743  0.9937
# d.o.f=2
#
# Weighted ARCH LM Tests
# ------------------------------------
#             Statistic Shape Scale P-Value
# ARCH Lag[3]  0.001839 0.500 2.000  0.9658
# ARCH Lag[5]  0.153800 1.440 1.667  0.9760
# ARCH Lag[7]  0.287649 2.315 1.543  0.9934
#
# Nyblom stability test
# ------------------------------------
# Joint Statistic:  116.4636
# Individual Statistics:
# mu      0.1464
# omega  16.9445
# alpha1  0.1957
# beta1   0.1753
# gamma1  0.2411
# shape   0.3356
#
# Asymptotic Critical Values (10% 5% 1%)
# Joint Statistic:     	 1.49 1.68 2.12
# Individual Statistic:	 0.35 0.47 0.75
#
# Sign Bias Test
# ------------------------------------
#                    t-value   prob sig
# Sign Bias           0.4801 0.6313
# Negative Sign Bias  0.6758 0.4993
# Positive Sign Bias  1.3221 0.1864
# Joint Effect        2.2548 0.5212
#
#
# Adjusted Pearson Goodness-of-Fit Test:
# ------------------------------------
#   group statistic p-value(g-1)
# 1    20     12.53       0.8619
# 2    30     18.68       0.9291
# 3    40     38.60       0.4881
# 4    50     41.70       0.7609
#
#
# Elapsed time : 0.3041849

# %% [markdown]
# Lets compare coefficients from all models

# %%
coefficients_s1 <- cbind(coef(garch11_s1),
                        coef(garch11t_s1),
                        coef(egearch_s1),
                        coef(egearcht_s1),  
                        coef(gjrgarch_s1),
                        coef(gjrgarcht_s1))

coefficients_s2 <- cbind(coef(garch11_s2),
                        coef(garch11t_s2),
                        coef(egearch_s2),
                        coef(egearcht_s2),  
                        coef(gjrgarch_s2),
                        coef(gjrgarcht_s2))

colnames(coefficients_s1) <- c("GARCH(1,1)","GARCH(1,1)-t","EGEARCH","EGEARCH-t","GJRGARCH","GJRGARCH-t")
colnames(coefficients_s2) <- c("GARCH(1,1)","GARCH(1,1)-t","EGEARCH","EGEARCH-t","GJRGARCH","GJRGARCH-t")
coefficients_s1
coefficients_s2
# Out:
# Warning message in cbind(coef(garch11_s1), coef(garch11t_s1), coef(egearch_s1), :
# "number of rows of result is not a multiple of vector length (arg 1)"Warning message in cbind(coef(garch11_s2), coef(garch11t_s2), coef(egearch_s2), :
# "number of rows of result is not a multiple of vector length (arg 1)"
#        GARCH(1,1)   GARCH(1,1)-t EGEARCH       EGEARCH-t     GJRGARCH
# mu     3.439761e-04 3.792423e-04  0.0001875816  0.0002522246 2.862009e-04
# omega  8.611419e-06 4.870699e-06 -0.3486161409 -0.2541636757 9.028889e-06
# alpha1 5.197756e-02 5.832527e-02 -0.0283896036 -0.0401640356 4.132965e-02
# beta1  9.081423e-01 9.207395e-01  0.9584353088  0.9701928497 9.061570e-01
# gamma1 3.439761e-04 6.331080e+00  0.1157985699  0.1319284169 2.090819e-02
# shape  8.611419e-06 3.792423e-04  0.0001875816  6.6338583792 2.862009e-04
#        GJRGARCH-t
# mu     3.372980e-04
# omega  5.596808e-06
# alpha1 4.690165e-02
# beta1  9.145088e-01
# gamma1 2.835271e-02
# shape  6.376036e+00
#        GARCH(1,1)   GARCH(1,1)-t EGEARCH       EGEARCH-t     GJRGARCH
# mu     2.045329e-04 6.330792e-04  0.0003562059  0.0006530288  2.453483e-04
# omega  2.616747e-06 8.000266e-07 -0.1445531366 -0.0954881037  4.171607e-07
# alpha1 3.141899e-02 3.591850e-02  0.0040706593 -0.0249284381  2.411478e-02
# beta1  9.598956e-01 9.630815e-01  0.9816478641  0.9886657839  9.905554e-01
# gamma1 2.045329e-04 4.310570e+00  0.1044026305  0.1289939149 -3.134042e-02
# shape  2.616747e-06 6.330792e-04  0.0003562059  4.2821568944  2.453483e-04
#        GJRGARCH-t
# mu      6.406183e-04
# omega   7.284427e-07
# alpha1  3.675931e-02
# beta1   9.659543e-01
# gamma1 -7.427303e-03
# shape   4.353438e+00

# %% [markdown]
# And lets check which model performs the best according to AIC

# %%
performance <- cbind(c(infocriteria(garch11_s1)["Akaike",],
                        infocriteria(garch11t_s1)["Akaike",],
                        infocriteria(egearch_s1)["Akaike",],
                        infocriteria(egearcht_s1)["Akaike",],
                        infocriteria(gjrgarch_s1)["Akaike",],
                        infocriteria(gjrgarcht_s1)["Akaike",]),
                     c(infocriteria(garch11_s2)["Akaike",],
                        infocriteria(garch11t_s2)["Akaike",],
                        infocriteria(egearch_s2)["Akaike",],
                        infocriteria(egearcht_s2)["Akaike",],
                        infocriteria(gjrgarch_s2)["Akaike",],
                        infocriteria(gjrgarcht_s2)["Akaike",]))
colnames(performance) <- c("subsample 1","subsample 2")
rownames(performance) <- c("GARCH(1,1)","GARCH(1,1)-t","EGEARCH","EGEARCH-t","GJRGARCH","GJRGARCH-t")
performance
# Out:
#              subsample 1 subsample 2
# GARCH(1,1)   -5.631082   -5.505024
# GARCH(1,1)-t -5.680149   -5.658568
# EGEARCH      -5.639045   -5.519763
# EGEARCH-t    -5.686201   -5.665514
# GJRGARCH     -5.629901   -5.513320
# GJRGARCH-t   -5.679122   -5.656772

# %% [markdown]
# GARCH(1,1)-t and EGEARCH-t perform the best in both subsamples (lowest AIC), but since I expect the first one to be more appropriate, I will proceed with GARCH(1,1)-t

# %% [markdown]
# Now lets perform dynamic forecast and set the forecast horizon to 200

# %%
for_garch11t_s1 = ugarchforecast(garch11t_s1, n.ahead = 1, n.roll = 200)
for_garch11t_s2 = ugarchforecast(garch11t_s2, n.ahead = 1, n.roll = 200)

# %%
plot.ts(garch11t_s1@fit$sigma, ylab = NA, xlim = c(0, length(INTC_s1_logret)), main = 'GARCH(1,1) volatility forecasted for first subsample ')
lines(c(rep(NA, length(INTC_s1_logret) - 200 - 1), for_garch11t_s1@forecast$sigma), col = 'red')


plot.ts(garch11t_s2@fit$sigma, ylab = NA, xlim = c(0, length(INTC_s2_logret)), main = 'GARCH(1,1) volatility forecasted for second subsample')
lines(c(rep(NA, length(INTC_s2_logret) - 200 - 1), for_garch11t_s2@forecast$sigma), col = 'red')
# Out:
# Plot with title "GARCH(1,1) volatility forecasted for first subsample "
# Plot with title "GARCH(1,1) volatility forecasted for second subsample"

# %% [markdown]
# Now, lets fit EWMA model (this is done by restricting omega to be equal to 0)

# %%
ewma_spec = ugarchspec(mean.model = list(armaOrder=c(0, 0)), variance.model = list(model = "iGARCH", garchOrder = c(1, 1)),
                       fixed.pars = list(omega = 0))

ewma_s1 = ugarchfit(ewma_spec,INTC_s1_logret , out.sample = 200)
ewma_s2 = ugarchfit(ewma_spec,INTC_s2_logret, out.sample = 200)

# %% [markdown]
# and forecast

# %%
for_ewma_s1 = ugarchforecast(ewma_s1, n.ahead = 1, n.roll = 200)
for_ewma_s2 = ugarchforecast(ewma_s2, n.ahead = 1, n.roll = 200)
# Out:
# Warning message in `setfixed<-`(`*tmp*`, value = as.list(pars)):
# "Unrecognized Parameter in Fixed Values: beta1...Ignored"Warning message in `setfixed<-`(`*tmp*`, value = as.list(pars)):
# "Unrecognized Parameter in Fixed Values: beta1...Ignored"

# %%
plot.ts(ewma_s1@fit$sigma, ylab = NA, xlim = c(0, length(INTC_s1_logret)), main = 'EWMA volatility forecasted for first subsample ')
lines(c(rep(NA, length(INTC_s1_logret) - 200 - 1), for_ewma_s1@forecast$sigma), col = 'red')


plot.ts(ewma_s2@fit$sigma, ylab = NA, xlim = c(0, length(INTC_s2_logret)), main = 'EWMA volatility forecasted for second subsample')
lines(c(rep(NA, length(INTC_s2_logret) - 200 - 1), for_ewma_s2@forecast$sigma), col = 'red')
# Out:
# Plot with title "EWMA volatility forecasted for first subsample "
# Plot with title "EWMA volatility forecasted for second subsample"

# %% [markdown]
# From the graphs we can see that they produce similar predictions (especially in second subsample), lets examine MSE.
#
# First I bind the prediction vectors

# %%
predictions  <- cbind(for_garch11t_s1@forecast$sigmaFor[1:200],
                      for_garch11t_s2@forecast$sigmaFor[1:200],
                      for_ewma_s1@forecast$sigmaFor[1:200],
                      for_ewma_s1@forecast$sigmaFor[1:200])

# %% [markdown]
# Then I calculate volatility proxy

# %%
vol_s1 <- (tail(INTC_s1_logret,200))^2
vol_s2 <- (tail(INTC_s2_logret,200))^2

# %% [markdown]
# And finally proceed to MSE

# %%
MSE_results <- cbind(MSE(y_pred = predictions[1], y_true = vol_s1),
                     MSE(y_pred = predictions[2], y_true = vol_s2),
                     MSE(y_pred = predictions[3], y_true = vol_s1),
                     MSE(y_pred = predictions[4], y_true = vol_s2))


colnames(MSE_results) <- c('GARCH(1,1)-t subsample 1',
                          'GARCH(1,1)-t subsample 2',
                          'EWMA subsample 1',
                          'EWMA subsample 2')

MSE_results
# Out:
#      GARCH(1,1)-t subsample 1 GARCH(1,1)-t subsample 2 EWMA subsample 1
# [1,] 9.604073e-05             9.471406e-05             0.000107786
#      EWMA subsample 2
# [1,] 0.0001085517

# %% [markdown]
# GARCH(1,1)-t appears to perform better than EWMA in terms of mean squared error in both subsamples
